# %%
# %load_ext autoreload
# %autoreload 2

# %%
"""
Purpose: To apply the documentation pipeline to package that will

1) Clean module files (fix docstring, relative paths, ect)
2) Create the requirements file
3) Create the setup.py file
4) Verify pip install works
5) setup the sphinx documentation folders and push to github pages of repo


"""
# Out:
# '\nPurpose: To apply the documentation pipeline to package that will\n\n1) Clean module files (fix docstring, relative paths, ect)\n2) Create the requirements file\n3) Create the setup.py file\n4) Verify pip install works\n5) setup the sphinx documentation folders and push to github pages of repo\n\n\n'

# %%
directory_name = "pytorch_tools"
directory_name
# Out:
# 'pytorch_tools'

# %% [markdown]
# # Cleaning current package

# %%
from pathlib import Path
directory = directory_name
directory = str(Path(f"./{directory}/").absolute())
directory
# Out:
# '/neurd_packages/pytorch_tools/pytorch_tools'

# %%
from python_tools import package_utils as pku
pku.clean_package_syntax(
    directory = [
        directory,
    ],
    create_init_if_not_exist = True,
    overwrite = True,
    verbose = True,
)
# Out:
# ---- working on directory: /neurd_packages/pytorch_tools/pytorch_tools ---
#    --- working on module: /neurd_packages/pytorch_tools/pytorch_tools/data_augmentation_utils.py ---
# output_path = /neurd_packages/pytorch_tools/pytorch_tools/data_augmentation_utils.py
# Search for package for /neurd_packages/pytorch_tools/pytorch_tools/data_augmentation_utils.py
# Matched to /neurd_packages/pytorch_tools/pytorch_tools/
# curr_mod = data_augmentation_utils, curr_package_name = pytorch_tools
#
#
# --- working on package: python_tools ---
# -- easy initial replacement --
# # of substitutions = 1
#   --> output_filepath = /neurd_packages/pytorch_tools/pytorch_tools/data_augmentation_utils.py
# -- harder initial replacement --
# # of substitutions = 0
#   --> output_filepath = /neurd_packages/pytorch_tools/pytorch_tools/data_augmentation_utils.py
#
#
# --- working on package: machine_learning_tools ---
# -- easy initial replacement --
# # of substitutions = 0
#   --> output_filepath = /neurd_packages/pytorch_tools/pytorch_tools/data_augmentation_utils.py
# -- harder initial replacement --
# # of substitutions = 0
#   --> output_filepath = /neurd_packages/pytorch_tools/pytorch_tools/data_augmentation_utils.py
#
#
# --- working on package: pytorch_tools ---
# -- easy initial replacement --
# # of substitutions = 5
#   --> output_filepath = /neurd_packages/pytorch_tools/pytorch_tools/data_augmentation_utils.py
# -- harder initial replacement --
# # of substitutions = 0
#   --> output_filepath = /neurd_packages/pytorch_tools/pytorch_tools/data_augmentation_utils.py
# -- easier relative replacement --
# # of substitutions = 4
#   --> output_filepath = /neurd_packages/pytorch_tools/pytorch_tools/data_augmentation_utils.py
# -- harder relative replacement --
# # of substitutions = 0
#   --> output_filepath = /neurd_packages/pytorch_tools/pytorch_tools/data_augmentation_utils.py
#
#
# --- working on package: graph_tools ---
# -- easy initial replacement --
# # of substitutions = 0
#   --> output_filepath = /neurd_packages/pytorch_tools/pytorch_tools/data_augmentation_utils.py
# -- harder initial replacement --
# # of substitutions = 0
#   --> output_filepath = /neurd_packages/pytorch_tools/pytorch_tools/data_augmentation_utils.py
#
#
# --- working on package: meshAfterParty ---
# -- easy initial replacement --
# # of substitutions = 0
#   --> output_filepath = /neurd_packages/pytorch_tools/pytorch_tools/data_augmentation_utils.py
# -- harder initial replacement --
# # of substitutions = 0
#   --> output_filepath = /neurd_packages/pytorch_tools/pytorch_tools/data_augmentation_utils.py
#
#
# --- working on package: neuron_morphology_tools ---
# -- easy initial replacement --
# # of substitutions = 0
#   --> output_filepath = /neurd_packages/pytorch_tools/pytorch_tools/data_augmentation_utils.py
# -- harder initial replacement --
# # of substitutions = 0
#   --> output_filepath = /neurd_packages/pytorch_tools/pytorch_tools/data_augmentation_utils.py
# # of multi-line strings = 1
# # of matches (unique = True) = 11
# # of modules replaced = 12
# ----non_pkg_mods_str =
# from copy import deepcopy
# import numpy as np
# import time
# import torch
# import torch.nn as nn
# import torch.nn.functional as F
# import torch_geometric as tg
#
#
# ----pkg_mods_str =
# #--- from pytorch_tools ---
# from . import geometric_dataset_utils as gdu
# from . import tensor_utils as tenu
#
# #--- from python_tools ---
# from python_tools import numpy_utils as nu
#
#
# ----own_mod_str =
# from . import data_augmentation_utils as dau
#    --- working on module: /neurd_packages/pytorch_tools/pytorch_tools/dgl_utils.py ---
# output_path = /neurd_packages/pytorch_tools/pytorch_tools/dgl_utils.py
# Search for package for /neurd_packages/pytorch_tools/pytorch_tools/dgl_utils.py
# Matched to /neurd_packages/pytorch_tools/pytorch_tools/
# curr_mod = dgl_utils, curr_package_name = pytorch_tools
#
#
# --- working on package: python_tools ---
# -- easy initial replacement --
# # of substitutions = 1
#   --> output_filepath = /neurd_packages/pytorch_tools/pytorch_tools/dgl_utils.py
# -- harder initial replacement --
# # of substitutions = 0
#   --> output_filepath = /neurd_packages/pytorch_tools/pytorch_tools/dgl_utils.py
#
#
# --- working on package: machine_learning_tools ---
# -- easy initial replacement --
# # of substitutions = 0
#   --> output_filepath = /neurd_packages/pytorch_tools/pytorch_tools/dgl_utils.py
# -- harder initial replacement --
# # of substitutions = 0
#   --> output_filepath = /neurd_packages/pytorch_tools/pytorch_tools/dgl_utils.py
#
#
# --- working on package: pytorch_tools ---
# -- easy initial replacement --
# # of substitutions = 1
#   --> output_filepath = /neurd_packages/pytorch_tools/pytorch_tools/dgl_utils.py
# -- harder initial replacement --
# # of substitutions = 0
#   --> output_filepath = /neurd_packages/pytorch_tools/pytorch_tools/dgl_utils.py
# -- easier relative replacement --
# # of substitutions = 1
#   --> output_filepath = /neurd_packages/pytorch_tools/pytorch_tools/dgl_utils.py
# -- harder relative replacement --
# # of substitutions = 0
#   --> output_filepath = /neurd_packages/pytorch_tools/pytorch_tools/dgl_utils.py
#
#
# --- working on package: graph_tools ---
# -- easy initial replacement --
# # of substitutions = 0
#   --> output_filepath = /neurd_packages/pytorch_tools/pytorch_tools/dgl_utils.py
# -- harder initial replacement --
# # of substitutions = 0
#   --> output_filepath = /neurd_packages/pytorch_tools/pytorch_tools/dgl_utils.py
#
#
# --- working on package: meshAfterParty ---
# -- easy initial replacement --
# # of substitutions = 0
#   --> output_filepath = /neurd_packages/pytorch_tools/pytorch_tools/dgl_utils.py
# -- harder initial replacement --
# # of substitutions = 0
#   --> output_filepath = /neurd_packages/pytorch_tools/pytorch_tools/dgl_utils.py
#
#
# --- working on package: neuron_morphology_tools ---
# -- easy initial replacement --
# # of substitutions = 0
#   --> output_filepath = /neurd_packages/pytorch_tools/pytorch_tools/dgl_utils.py
# -- harder initial replacement --
# # of substitutions = 0
#   --> output_filepath = /neurd_packages/pytorch_tools/pytorch_tools/dgl_utils.py
# # of multi-line strings = 0
# # of matches (unique = True) = 5
# # of modules replaced = 5
# ----non_pkg_mods_str =
# import dgl
# import networkx as nx
# import numpy as np
#
#
# ----pkg_mods_str =
# #--- from python_tools ---
# from python_tools import networkx_utils as xu
#
#
# ----own_mod_str =
# from . import dgl_utils as dglu
#    --- working on module: /neurd_packages/pytorch_tools/pytorch_tools/evaluation_utils.py ---
# output_path = /neurd_packages/pytorch_tools/pytorch_tools/evaluation_utils.py
# Search for package for /neurd_packages/pytorch_tools/pytorch_tools/evaluation_utils.py
# Matched to /neurd_packages/pytorch_tools/pytorch_tools/
# curr_mod = evaluation_utils, curr_package_name = pytorch_tools
#
#
# --- working on package: python_tools ---
# -- easy initial replacement --
# # of substitutions = 0
#   --> output_filepath = /neurd_packages/pytorch_tools/pytorch_tools/evaluation_utils.py
# -- harder initial replacement --
# # of substitutions = 0
#   --> output_filepath = /neurd_packages/pytorch_tools/pytorch_tools/evaluation_utils.py
#
#
# --- working on package: machine_learning_tools ---
# -- easy initial replacement --
# # of substitutions = 0
#   --> output_filepath = /neurd_packages/pytorch_tools/pytorch_tools/evaluation_utils.py
# -- harder initial replacement --
# # of substitutions = 0
#   --> output_filepath = /neurd_packages/pytorch_tools/pytorch_tools/evaluation_utils.py
#
#
# --- working on package: pytorch_tools ---
# -- easy initial replacement --
# # of substitutions = 1
#   --> output_filepath = /neurd_packages/pytorch_tools/pytorch_tools/evaluation_utils.py
# -- harder initial replacement --
# # of substitutions = 0
#   --> output_filepath = /neurd_packages/pytorch_tools/pytorch_tools/evaluation_utils.py
# -- easier relative replacement --
# # of substitutions = 1
#   --> output_filepath = /neurd_packages/pytorch_tools/pytorch_tools/evaluation_utils.py
# -- harder relative replacement --
# # of substitutions = 0
#   --> output_filepath = /neurd_packages/pytorch_tools/pytorch_tools/evaluation_utils.py
#
#
# --- working on package: graph_tools ---
# -- easy initial replacement --
# # of substitutions = 0
#   --> output_filepath = /neurd_packages/pytorch_tools/pytorch_tools/evaluation_utils.py
# -- harder initial replacement --
# # of substitutions = 0
#   --> output_filepath = /neurd_packages/pytorch_tools/pytorch_tools/evaluation_utils.py
#
#
# --- working on package: meshAfterParty ---
# -- easy initial replacement --
# # of substitutions = 0
#   --> output_filepath = /neurd_packages/pytorch_tools/pytorch_tools/evaluation_utils.py
# -- harder initial replacement --
# # of substitutions = 0
#   --> output_filepath = /neurd_packages/pytorch_tools/pytorch_tools/evaluation_utils.py
#
#
# --- working on package: neuron_morphology_tools ---
# -- easy initial replacement --
# # of substitutions = 0
#   --> output_filepath = /neurd_packages/pytorch_tools/pytorch_tools/evaluation_utils.py
# -- harder initial replacement --
# # of substitutions = 0
#   --> output_filepath = /neurd_packages/pytorch_tools/pytorch_tools/evaluation_utils.py
# # of multi-line strings = 0
# # of matches (unique = True) = 3
# # of modules replaced = 3
# ----non_pkg_mods_str =
# import numpy as np
# import torch
#
#
# ----pkg_mods_str =
#
#
#
# ----own_mod_str =
# from . import evaluation_utils as evu
#    --- working on module: /neurd_packages/pytorch_tools/pytorch_tools/geometric_dataset_utils.py ---
# output_path = /neurd_packages/pytorch_tools/pytorch_tools/geometric_dataset_utils.py
# Search for package for /neurd_packages/pytorch_tools/pytorch_tools/geometric_dataset_utils.py
# Matched to /neurd_packages/pytorch_tools/pytorch_tools/
# curr_mod = geometric_dataset_utils, curr_package_name = pytorch_tools
#
#
# --- working on package: python_tools ---
# -- easy initial replacement --
# # of substitutions = 6
#   --> output_filepath = /neurd_packages/pytorch_tools/pytorch_tools/geometric_dataset_utils.py
# -- harder initial replacement --
# # of substitutions = 2
#   --> output_filepath = /neurd_packages/pytorch_tools/pytorch_tools/geometric_dataset_utils.py
#
#
# --- working on package: machine_learning_tools ---
# -- easy initial replacement --
# # of substitutions = 0
#   --> output_filepath = /neurd_packages/pytorch_tools/pytorch_tools/geometric_dataset_utils.py
# -- harder initial replacement --
# # of substitutions = 0
#   --> output_filepath = /neurd_packages/pytorch_tools/pytorch_tools/geometric_dataset_utils.py
#
#
# --- working on package: pytorch_tools ---
# -- easy initial replacement --
# # of substitutions = 4
#   --> output_filepath = /neurd_packages/pytorch_tools/pytorch_tools/geometric_dataset_utils.py
# -- harder initial replacement --
# # of substitutions = 0
#   --> output_filepath = /neurd_packages/pytorch_tools/pytorch_tools/geometric_dataset_utils.py
# -- easier relative replacement --
# # of substitutions = 3
#   --> output_filepath = /neurd_packages/pytorch_tools/pytorch_tools/geometric_dataset_utils.py
# -- harder relative replacement --
# # of substitutions = 0
#   --> output_filepath = /neurd_packages/pytorch_tools/pytorch_tools/geometric_dataset_utils.py
#
#
# --- working on package: graph_tools ---
# -- easy initial replacement --
# # of substitutions = 0
#   --> output_filepath = /neurd_packages/pytorch_tools/pytorch_tools/geometric_dataset_utils.py
# -- harder initial replacement --
# # of substitutions = 0
#   --> output_filepath = /neurd_packages/pytorch_tools/pytorch_tools/geometric_dataset_utils.py
#
#
# --- working on package: meshAfterParty ---
# -- easy initial replacement --
# # of substitutions = 1
#   --> output_filepath = /neurd_packages/pytorch_tools/pytorch_tools/geometric_dataset_utils.py
# -- harder initial replacement --
# # of substitutions = 1
#   --> output_filepath = /neurd_packages/pytorch_tools/pytorch_tools/geometric_dataset_utils.py
#
#
# --- working on package: neuron_morphology_tools ---
# -- easy initial replacement --
# # of substitutions = 1
#   --> output_filepath = /neurd_packages/pytorch_tools/pytorch_tools/geometric_dataset_utils.py
# -- harder initial replacement --
# # of substitutions = 0
#   --> output_filepath = /neurd_packages/pytorch_tools/pytorch_tools/geometric_dataset_utils.py
# # of multi-line strings = 0
# # of matches (unique = True) = 24
# # of modules replaced = 29
# ----non_pkg_mods_str =
# from copy import deepcopy
# from pathlib import Path
# from torch_geometric import transforms
# from torch_geometric.data import Data
# from torch_geometric.data import DenseDataLoader
# from torch_geometric.data import InMemoryDataset, download_url
# from torch_geometric.loader import DataLoader
# from torch_geometric.nn import GCNConv
# from torch_geometric.utils import train_test_split_edges
# import numpy as np
# import pandas as pd
# import time
# import torch
# import torch_geometric.transforms as T
#
#
# ----pkg_mods_str =
# #--- from pytorch_tools ---
# from . import preprocessing_utils as pret
# from . import tensor_utils as tenu
#
# #--- from neuron_morphology_tools ---
# from neuron_morphology_tools import neuron_nx_io as nxio
#
# #--- from python_tools ---
# from python_tools import networkx_utils as xu
# from python_tools import numpy_utils as nu
# from python_tools import pandas_utils as pu
# from python_tools import regex_utils as reu
# from python_tools import system_utils as su
# from python_tools.tqdm_utils import tqdm
#
#
# ----own_mod_str =
# from . import geometric_dataset_utils as gdu
#    --- working on module: /neurd_packages/pytorch_tools/pytorch_tools/geometric_models.py ---
# output_path = /neurd_packages/pytorch_tools/pytorch_tools/geometric_models.py
# Search for package for /neurd_packages/pytorch_tools/pytorch_tools/geometric_models.py
# Matched to /neurd_packages/pytorch_tools/pytorch_tools/
# curr_mod = geometric_models, curr_package_name = pytorch_tools
#
#
# --- working on package: python_tools ---
# -- easy initial replacement --
# # of substitutions = 1
#   --> output_filepath = /neurd_packages/pytorch_tools/pytorch_tools/geometric_models.py
# -- harder initial replacement --
# # of substitutions = 0
#   --> output_filepath = /neurd_packages/pytorch_tools/pytorch_tools/geometric_models.py
#
#
# --- working on package: machine_learning_tools ---
# -- easy initial replacement --
# # of substitutions = 0
#   --> output_filepath = /neurd_packages/pytorch_tools/pytorch_tools/geometric_models.py
# -- harder initial replacement --
# # of substitutions = 0
#   --> output_filepath = /neurd_packages/pytorch_tools/pytorch_tools/geometric_models.py
#
#
# --- working on package: pytorch_tools ---
# -- easy initial replacement --
# # of substitutions = 4
#   --> output_filepath = /neurd_packages/pytorch_tools/pytorch_tools/geometric_models.py
# -- harder initial replacement --
# # of substitutions = 0
#   --> output_filepath = /neurd_packages/pytorch_tools/pytorch_tools/geometric_models.py
# -- easier relative replacement --
# # of substitutions = 4
#   --> output_filepath = /neurd_packages/pytorch_tools/pytorch_tools/geometric_models.py
# -- harder relative replacement --
# # of substitutions = 0
#   --> output_filepath = /neurd_packages/pytorch_tools/pytorch_tools/geometric_models.py
#
#
# --- working on package: graph_tools ---
# -- easy initial replacement --
# # of substitutions = 0
#   --> output_filepath = /neurd_packages/pytorch_tools/pytorch_tools/geometric_models.py
# -- harder initial replacement --
# # of substitutions = 0
#   --> output_filepath = /neurd_packages/pytorch_tools/pytorch_tools/geometric_models.py
#
#
# --- working on package: meshAfterParty ---
# -- easy initial replacement --
# # of substitutions = 0
#   --> output_filepath = /neurd_packages/pytorch_tools/pytorch_tools/geometric_models.py
# -- harder initial replacement --
# # of substitutions = 0
#   --> output_filepath = /neurd_packages/pytorch_tools/pytorch_tools/geometric_models.py
#
#
# --- working on package: neuron_morphology_tools ---
# -- easy initial replacement --
# # of substitutions = 0
#   --> output_filepath = /neurd_packages/pytorch_tools/pytorch_tools/geometric_models.py
# -- harder initial replacement --
# # of substitutions = 0
#   --> output_filepath = /neurd_packages/pytorch_tools/pytorch_tools/geometric_models.py
# # of multi-line strings = 6
# # of matches (unique = True) = 18
# # of modules replaced = 22
# ----non_pkg_mods_str =
# from collections import namedtuple
# from math import ceil
# from torch.nn import Linear
# from torch_geometric.nn import DenseGCNConv as DenseGCNConv, dense_diff_pool
# from torch_geometric.nn import GATConv
# from torch_geometric.nn import GCNConv
# from torch_geometric.nn import SAGEConv
# from torch_geometric.nn import global_mean_pool,global_add_pool,global_mean_pool,global_sort_pool,global_max_pool
# import dgl
# import dgl.function as fn
# import numpy as np
# import torch
# import torch as th
# import torch.nn as nn
# import torch.nn.functional as F
#
#
# ----pkg_mods_str =
# #--- from pytorch_tools ---
# from . import dgl_utils as dglu
# from . import geometric_tensor_utils as gtu
#
# #--- from python_tools ---
# from python_tools import numpy_utils as nu
#
#
# ----own_mod_str =
#
#    --- working on module: /neurd_packages/pytorch_tools/pytorch_tools/geometric_models_overload.py ---
# output_path = /neurd_packages/pytorch_tools/pytorch_tools/geometric_models_overload.py
# Search for package for /neurd_packages/pytorch_tools/pytorch_tools/geometric_models_overload.py
# Matched to /neurd_packages/pytorch_tools/pytorch_tools/
# curr_mod = geometric_models_overload, curr_package_name = pytorch_tools
#
#
# --- working on package: python_tools ---
# -- easy initial replacement --
# # of substitutions = 0
#   --> output_filepath = /neurd_packages/pytorch_tools/pytorch_tools/geometric_models_overload.py
# -- harder initial replacement --
# # of substitutions = 0
#   --> output_filepath = /neurd_packages/pytorch_tools/pytorch_tools/geometric_models_overload.py
#
#
# --- working on package: machine_learning_tools ---
# -- easy initial replacement --
# # of substitutions = 0
#   --> output_filepath = /neurd_packages/pytorch_tools/pytorch_tools/geometric_models_overload.py
# -- harder initial replacement --
# # of substitutions = 0
#   --> output_filepath = /neurd_packages/pytorch_tools/pytorch_tools/geometric_models_overload.py
#
#
# --- working on package: pytorch_tools ---
# -- easy initial replacement --
# # of substitutions = 0
#   --> output_filepath = /neurd_packages/pytorch_tools/pytorch_tools/geometric_models_overload.py
# -- harder initial replacement --
# # of substitutions = 0
#   --> output_filepath = /neurd_packages/pytorch_tools/pytorch_tools/geometric_models_overload.py
# -- easier relative replacement --
# # of substitutions = 0
#   --> output_filepath = /neurd_packages/pytorch_tools/pytorch_tools/geometric_models_overload.py
# -- harder relative replacement --
# # of substitutions = 0
#   --> output_filepath = /neurd_packages/pytorch_tools/pytorch_tools/geometric_models_overload.py
#
#
# --- working on package: graph_tools ---
# -- easy initial replacement --
# # of substitutions = 0
#   --> output_filepath = /neurd_packages/pytorch_tools/pytorch_tools/geometric_models_overload.py
# -- harder initial replacement --
# # of substitutions = 0
#   --> output_filepath = /neurd_packages/pytorch_tools/pytorch_tools/geometric_models_overload.py
#
#
# --- working on package: meshAfterParty ---
# -- easy initial replacement --
# # of substitutions = 0
#   --> output_filepath = /neurd_packages/pytorch_tools/pytorch_tools/geometric_models_overload.py
# -- harder initial replacement --
# # of substitutions = 0
#   --> output_filepath = /neurd_packages/pytorch_tools/pytorch_tools/geometric_models_overload.py
#
#
# --- working on package: neuron_morphology_tools ---
# -- easy initial replacement --
# # of substitutions = 0
#   --> output_filepath = /neurd_packages/pytorch_tools/pytorch_tools/geometric_models_overload.py
# -- harder initial replacement --
# # of substitutions = 0
#   --> output_filepath = /neurd_packages/pytorch_tools/pytorch_tools/geometric_models_overload.py
# # of multi-line strings = 0
# # of matches (unique = True) = 9
# # of modules replaced = 9
# ----non_pkg_mods_str =
# from torch import Tensor
# from torch_geometric.nn import GCNConv as gc
# from torch_geometric.typing import Adj, OptTensor, PairTensor
# from torch_geometric.utils import add_remaining_self_loops
# from typing import Optional, Tuple
# from typing import Union
# import copy
# import torch
# import torch_sparse
#
#
# ----pkg_mods_str =
#
#
#
# ----own_mod_str =
#
#    --- working on module: /neurd_packages/pytorch_tools/pytorch_tools/geometric_tensor_utils.py ---
# output_path = /neurd_packages/pytorch_tools/pytorch_tools/geometric_tensor_utils.py
# Search for package for /neurd_packages/pytorch_tools/pytorch_tools/geometric_tensor_utils.py
# Matched to /neurd_packages/pytorch_tools/pytorch_tools/
# curr_mod = geometric_tensor_utils, curr_package_name = pytorch_tools
#
#
# --- working on package: python_tools ---
# -- easy initial replacement --
# # of substitutions = 0
#   --> output_filepath = /neurd_packages/pytorch_tools/pytorch_tools/geometric_tensor_utils.py
# -- harder initial replacement --
# # of substitutions = 0
#   --> output_filepath = /neurd_packages/pytorch_tools/pytorch_tools/geometric_tensor_utils.py
#
#
# --- working on package: machine_learning_tools ---
# -- easy initial replacement --
# # of substitutions = 0
#   --> output_filepath = /neurd_packages/pytorch_tools/pytorch_tools/geometric_tensor_utils.py
# -- harder initial replacement --
# # of substitutions = 0
#   --> output_filepath = /neurd_packages/pytorch_tools/pytorch_tools/geometric_tensor_utils.py
#
#
# --- working on package: pytorch_tools ---
# -- easy initial replacement --
# # of substitutions = 3
#   --> output_filepath = /neurd_packages/pytorch_tools/pytorch_tools/geometric_tensor_utils.py
# -- harder initial replacement --
# # of substitutions = 0
#   --> output_filepath = /neurd_packages/pytorch_tools/pytorch_tools/geometric_tensor_utils.py
# -- easier relative replacement --
# # of substitutions = 2
#   --> output_filepath = /neurd_packages/pytorch_tools/pytorch_tools/geometric_tensor_utils.py
# -- harder relative replacement --
# # of substitutions = 0
#   --> output_filepath = /neurd_packages/pytorch_tools/pytorch_tools/geometric_tensor_utils.py
#
#
# --- working on package: graph_tools ---
# -- easy initial replacement --
# # of substitutions = 0
#   --> output_filepath = /neurd_packages/pytorch_tools/pytorch_tools/geometric_tensor_utils.py
# -- harder initial replacement --
# # of substitutions = 0
#   --> output_filepath = /neurd_packages/pytorch_tools/pytorch_tools/geometric_tensor_utils.py
#
#
# --- working on package: meshAfterParty ---
# -- easy initial replacement --
# # of substitutions = 0
#   --> output_filepath = /neurd_packages/pytorch_tools/pytorch_tools/geometric_tensor_utils.py
# -- harder initial replacement --
# # of substitutions = 0
#   --> output_filepath = /neurd_packages/pytorch_tools/pytorch_tools/geometric_tensor_utils.py
#
#
# --- working on package: neuron_morphology_tools ---
# -- easy initial replacement --
# # of substitutions = 0
#   --> output_filepath = /neurd_packages/pytorch_tools/pytorch_tools/geometric_tensor_utils.py
# -- harder initial replacement --
# # of substitutions = 0
#   --> output_filepath = /neurd_packages/pytorch_tools/pytorch_tools/geometric_tensor_utils.py
# # of multi-line strings = 0
# # of matches (unique = True) = 5
# # of modules replaced = 5
# ----non_pkg_mods_str =
# import torch
# import torch_geometric.nn as nn
# import torch_geometric.nn as nn_geo
#
#
# ----pkg_mods_str =
# #--- from pytorch_tools ---
# from . import tensor_utils as tenu
#
#
# ----own_mod_str =
# from . import geometric_tensor_utils as gtu
#    --- working on module: /neurd_packages/pytorch_tools/pytorch_tools/geometric_utils.py ---
# output_path = /neurd_packages/pytorch_tools/pytorch_tools/geometric_utils.py
# Search for package for /neurd_packages/pytorch_tools/pytorch_tools/geometric_utils.py
# Matched to /neurd_packages/pytorch_tools/pytorch_tools/
# curr_mod = geometric_utils, curr_package_name = pytorch_tools
#
#
# --- working on package: python_tools ---
# -- easy initial replacement --
# # of substitutions = 0
#   --> output_filepath = /neurd_packages/pytorch_tools/pytorch_tools/geometric_utils.py
# -- harder initial replacement --
# # of substitutions = 0
#   --> output_filepath = /neurd_packages/pytorch_tools/pytorch_tools/geometric_utils.py
#
#
# --- working on package: machine_learning_tools ---
# -- easy initial replacement --
# # of substitutions = 0
#   --> output_filepath = /neurd_packages/pytorch_tools/pytorch_tools/geometric_utils.py
# -- harder initial replacement --
# # of substitutions = 0
#   --> output_filepath = /neurd_packages/pytorch_tools/pytorch_tools/geometric_utils.py
#
#
# --- working on package: pytorch_tools ---
# -- easy initial replacement --
# # of substitutions = 0
#   --> output_filepath = /neurd_packages/pytorch_tools/pytorch_tools/geometric_utils.py
# -- harder initial replacement --
# # of substitutions = 0
#   --> output_filepath = /neurd_packages/pytorch_tools/pytorch_tools/geometric_utils.py
# -- easier relative replacement --
# # of substitutions = 0
#   --> output_filepath = /neurd_packages/pytorch_tools/pytorch_tools/geometric_utils.py
# -- harder relative replacement --
# # of substitutions = 0
#   --> output_filepath = /neurd_packages/pytorch_tools/pytorch_tools/geometric_utils.py
#
#
# --- working on package: graph_tools ---
# -- easy initial replacement --
# # of substitutions = 0
#   --> output_filepath = /neurd_packages/pytorch_tools/pytorch_tools/geometric_utils.py
# -- harder initial replacement --
# # of substitutions = 0
#   --> output_filepath = /neurd_packages/pytorch_tools/pytorch_tools/geometric_utils.py
#
#
# --- working on package: meshAfterParty ---
# -- easy initial replacement --
# # of substitutions = 0
#   --> output_filepath = /neurd_packages/pytorch_tools/pytorch_tools/geometric_utils.py
# -- harder initial replacement --
# # of substitutions = 0
#   --> output_filepath = /neurd_packages/pytorch_tools/pytorch_tools/geometric_utils.py
#
#
# --- working on package: neuron_morphology_tools ---
# -- easy initial replacement --
# # of substitutions = 0
#   --> output_filepath = /neurd_packages/pytorch_tools/pytorch_tools/geometric_utils.py
# -- harder initial replacement --
# # of substitutions = 0
#   --> output_filepath = /neurd_packages/pytorch_tools/pytorch_tools/geometric_utils.py
# # of multi-line strings = 0
# # of matches (unique = True) = 1
# # of modules replaced = 1
# ----non_pkg_mods_str =
# import torch_geometric.utils as geou
#
#
# ----pkg_mods_str =
#
#
#
# ----own_mod_str =
#
#    --- working on module: /neurd_packages/pytorch_tools/pytorch_tools/hierarchical_utils.py ---
# output_path = /neurd_packages/pytorch_tools/pytorch_tools/hierarchical_utils.py
# Search for package for /neurd_packages/pytorch_tools/pytorch_tools/hierarchical_utils.py
# Matched to /neurd_packages/pytorch_tools/pytorch_tools/
# curr_mod = hierarchical_utils, curr_package_name = pytorch_tools
#
#
# --- working on package: python_tools ---
# -- easy initial replacement --
# # of substitutions = 1
#   --> output_filepath = /neurd_packages/pytorch_tools/pytorch_tools/hierarchical_utils.py
# -- harder initial replacement --
# # of substitutions = 0
#   --> output_filepath = /neurd_packages/pytorch_tools/pytorch_tools/hierarchical_utils.py
#
#
# --- working on package: machine_learning_tools ---
# -- easy initial replacement --
# # of substitutions = 0
#   --> output_filepath = /neurd_packages/pytorch_tools/pytorch_tools/hierarchical_utils.py
# -- harder initial replacement --
# # of substitutions = 0
#   --> output_filepath = /neurd_packages/pytorch_tools/pytorch_tools/hierarchical_utils.py
#
#
# --- working on package: pytorch_tools ---
# -- easy initial replacement --
# # of substitutions = 7
#   --> output_filepath = /neurd_packages/pytorch_tools/pytorch_tools/hierarchical_utils.py
# -- harder initial replacement --
# # of substitutions = 2
#   --> output_filepath = /neurd_packages/pytorch_tools/pytorch_tools/hierarchical_utils.py
# -- easier relative replacement --
# # of substitutions = 7
#   --> output_filepath = /neurd_packages/pytorch_tools/pytorch_tools/hierarchical_utils.py
# -- harder relative replacement --
# # of substitutions = 2
#   --> output_filepath = /neurd_packages/pytorch_tools/pytorch_tools/hierarchical_utils.py
#
#
# --- working on package: graph_tools ---
# -- easy initial replacement --
# # of substitutions = 0
#   --> output_filepath = /neurd_packages/pytorch_tools/pytorch_tools/hierarchical_utils.py
# -- harder initial replacement --
# # of substitutions = 0
#   --> output_filepath = /neurd_packages/pytorch_tools/pytorch_tools/hierarchical_utils.py
#
#
# --- working on package: meshAfterParty ---
# -- easy initial replacement --
# # of substitutions = 0
#   --> output_filepath = /neurd_packages/pytorch_tools/pytorch_tools/hierarchical_utils.py
# -- harder initial replacement --
# # of substitutions = 0
#   --> output_filepath = /neurd_packages/pytorch_tools/pytorch_tools/hierarchical_utils.py
#
#
# --- working on package: neuron_morphology_tools ---
# -- easy initial replacement --
# # of substitutions = 0
#   --> output_filepath = /neurd_packages/pytorch_tools/pytorch_tools/hierarchical_utils.py
# -- harder initial replacement --
# # of substitutions = 0
#   --> output_filepath = /neurd_packages/pytorch_tools/pytorch_tools/hierarchical_utils.py
# # of multi-line strings = 0
# # of matches (unique = True) = 17
# # of modules replaced = 21
# ----non_pkg_mods_str =
# from torch.nn import Linear
# from torch_geometric.nn import global_mean_pool,global_add_pool,global_mean_pool,global_sort_pool,global_max_pool
# import numpy as np
# import pandas as pd
# import torch
# import torch as th
# import torch.nn as nn
# import torch.nn.functional as F
#
#
# ----pkg_mods_str =
# #--- from pytorch_tools ---
# from . import data_augmentation_utils as dau
# from . import evaluation_utils as evu
# from . import geometric_tensor_utils as gtu
# from . import parameters_utils as paru
# from . import tensor_utils as tenu
# from .geometric_models import ClassifierBase
# from .geometric_models_overload import GCNConv
#
# #--- from python_tools ---
# from python_tools import numpy_utils as nu
#
#
# ----own_mod_str =
# from . import hierarchical_utils as hru
#    --- working on module: /neurd_packages/pytorch_tools/pytorch_tools/loss_utils.py ---
# output_path = /neurd_packages/pytorch_tools/pytorch_tools/loss_utils.py
# Search for package for /neurd_packages/pytorch_tools/pytorch_tools/loss_utils.py
# Matched to /neurd_packages/pytorch_tools/pytorch_tools/
# curr_mod = loss_utils, curr_package_name = pytorch_tools
#
#
# --- working on package: python_tools ---
# -- easy initial replacement --
# # of substitutions = 0
#   --> output_filepath = /neurd_packages/pytorch_tools/pytorch_tools/loss_utils.py
# -- harder initial replacement --
# # of substitutions = 0
#   --> output_filepath = /neurd_packages/pytorch_tools/pytorch_tools/loss_utils.py
#
#
# --- working on package: machine_learning_tools ---
# -- easy initial replacement --
# # of substitutions = 0
#   --> output_filepath = /neurd_packages/pytorch_tools/pytorch_tools/loss_utils.py
# -- harder initial replacement --
# # of substitutions = 0
#   --> output_filepath = /neurd_packages/pytorch_tools/pytorch_tools/loss_utils.py
#
#
# --- working on package: pytorch_tools ---
# -- easy initial replacement --
# # of substitutions = 0
#   --> output_filepath = /neurd_packages/pytorch_tools/pytorch_tools/loss_utils.py
# -- harder initial replacement --
# # of substitutions = 0
#   --> output_filepath = /neurd_packages/pytorch_tools/pytorch_tools/loss_utils.py
# -- easier relative replacement --
# # of substitutions = 0
#   --> output_filepath = /neurd_packages/pytorch_tools/pytorch_tools/loss_utils.py
# -- harder relative replacement --
# # of substitutions = 0
#   --> output_filepath = /neurd_packages/pytorch_tools/pytorch_tools/loss_utils.py
#
#
# --- working on package: graph_tools ---
# -- easy initial replacement --
# # of substitutions = 0
#   --> output_filepath = /neurd_packages/pytorch_tools/pytorch_tools/loss_utils.py
# -- harder initial replacement --
# # of substitutions = 0
#   --> output_filepath = /neurd_packages/pytorch_tools/pytorch_tools/loss_utils.py
#
#
# --- working on package: meshAfterParty ---
# -- easy initial replacement --
# # of substitutions = 0
#   --> output_filepath = /neurd_packages/pytorch_tools/pytorch_tools/loss_utils.py
# -- harder initial replacement --
# # of substitutions = 0
#   --> output_filepath = /neurd_packages/pytorch_tools/pytorch_tools/loss_utils.py
#
#
# --- working on package: neuron_morphology_tools ---
# -- easy initial replacement --
# # of substitutions = 0
#   --> output_filepath = /neurd_packages/pytorch_tools/pytorch_tools/loss_utils.py
# -- harder initial replacement --
# # of substitutions = 0
#   --> output_filepath = /neurd_packages/pytorch_tools/pytorch_tools/loss_utils.py
# # of multi-line strings = 1
# # of matches (unique = True) = 0
# # of modules replaced = 1
# ----non_pkg_mods_str =
#
#
#
# ----pkg_mods_str =
#
#
#
# ----own_mod_str =
#
#    --- working on module: /neurd_packages/pytorch_tools/pytorch_tools/model_utils.py ---
# output_path = /neurd_packages/pytorch_tools/pytorch_tools/model_utils.py
# Search for package for /neurd_packages/pytorch_tools/pytorch_tools/model_utils.py
# Matched to /neurd_packages/pytorch_tools/pytorch_tools/
# curr_mod = model_utils, curr_package_name = pytorch_tools
#
#
# --- working on package: python_tools ---
# -- easy initial replacement --
# # of substitutions = 0
#   --> output_filepath = /neurd_packages/pytorch_tools/pytorch_tools/model_utils.py
# -- harder initial replacement --
# # of substitutions = 0
#   --> output_filepath = /neurd_packages/pytorch_tools/pytorch_tools/model_utils.py
#
#
# --- working on package: machine_learning_tools ---
# -- easy initial replacement --
# # of substitutions = 0
#   --> output_filepath = /neurd_packages/pytorch_tools/pytorch_tools/model_utils.py
# -- harder initial replacement --
# # of substitutions = 0
#   --> output_filepath = /neurd_packages/pytorch_tools/pytorch_tools/model_utils.py
#
#
# --- working on package: pytorch_tools ---
# -- easy initial replacement --
# # of substitutions = 1
#   --> output_filepath = /neurd_packages/pytorch_tools/pytorch_tools/model_utils.py
# -- harder initial replacement --
# # of substitutions = 0
#   --> output_filepath = /neurd_packages/pytorch_tools/pytorch_tools/model_utils.py
# -- easier relative replacement --
# # of substitutions = 1
#   --> output_filepath = /neurd_packages/pytorch_tools/pytorch_tools/model_utils.py
# -- harder relative replacement --
# # of substitutions = 0
#   --> output_filepath = /neurd_packages/pytorch_tools/pytorch_tools/model_utils.py
#
#
# --- working on package: graph_tools ---
# -- easy initial replacement --
# # of substitutions = 0
#   --> output_filepath = /neurd_packages/pytorch_tools/pytorch_tools/model_utils.py
# -- harder initial replacement --
# # of substitutions = 0
#   --> output_filepath = /neurd_packages/pytorch_tools/pytorch_tools/model_utils.py
#
#
# --- working on package: meshAfterParty ---
# -- easy initial replacement --
# # of substitutions = 0
#   --> output_filepath = /neurd_packages/pytorch_tools/pytorch_tools/model_utils.py
# -- harder initial replacement --
# # of substitutions = 0
#   --> output_filepath = /neurd_packages/pytorch_tools/pytorch_tools/model_utils.py
#
#
# --- working on package: neuron_morphology_tools ---
# -- easy initial replacement --
# # of substitutions = 0
#   --> output_filepath = /neurd_packages/pytorch_tools/pytorch_tools/model_utils.py
# -- harder initial replacement --
# # of substitutions = 0
#   --> output_filepath = /neurd_packages/pytorch_tools/pytorch_tools/model_utils.py
# # of multi-line strings = 0
# # of matches (unique = True) = 2
# # of modules replaced = 2
# ----non_pkg_mods_str =
# import torch
#
#
# ----pkg_mods_str =
#
#
#
# ----own_mod_str =
# from . import model_utils as mdlu
#    --- working on module: /neurd_packages/pytorch_tools/pytorch_tools/parameters_utils.py ---
# output_path = /neurd_packages/pytorch_tools/pytorch_tools/parameters_utils.py
# Search for package for /neurd_packages/pytorch_tools/pytorch_tools/parameters_utils.py
# Matched to /neurd_packages/pytorch_tools/pytorch_tools/
# curr_mod = parameters_utils, curr_package_name = pytorch_tools
#
#
# --- working on package: python_tools ---
# -- easy initial replacement --
# # of substitutions = 0
#   --> output_filepath = /neurd_packages/pytorch_tools/pytorch_tools/parameters_utils.py
# -- harder initial replacement --
# # of substitutions = 0
#   --> output_filepath = /neurd_packages/pytorch_tools/pytorch_tools/parameters_utils.py
#
#
# --- working on package: machine_learning_tools ---
# -- easy initial replacement --
# # of substitutions = 0
#   --> output_filepath = /neurd_packages/pytorch_tools/pytorch_tools/parameters_utils.py
# -- harder initial replacement --
# # of substitutions = 0
#   --> output_filepath = /neurd_packages/pytorch_tools/pytorch_tools/parameters_utils.py
#
#
# --- working on package: pytorch_tools ---
# -- easy initial replacement --
# # of substitutions = 1
#   --> output_filepath = /neurd_packages/pytorch_tools/pytorch_tools/parameters_utils.py
# -- harder initial replacement --
# # of substitutions = 0
#   --> output_filepath = /neurd_packages/pytorch_tools/pytorch_tools/parameters_utils.py
# -- easier relative replacement --
# # of substitutions = 1
#   --> output_filepath = /neurd_packages/pytorch_tools/pytorch_tools/parameters_utils.py
# -- harder relative replacement --
# # of substitutions = 0
#   --> output_filepath = /neurd_packages/pytorch_tools/pytorch_tools/parameters_utils.py
#
#
# --- working on package: graph_tools ---
# -- easy initial replacement --
# # of substitutions = 0
#   --> output_filepath = /neurd_packages/pytorch_tools/pytorch_tools/parameters_utils.py
# -- harder initial replacement --
# # of substitutions = 0
#   --> output_filepath = /neurd_packages/pytorch_tools/pytorch_tools/parameters_utils.py
#
#
# --- working on package: meshAfterParty ---
# -- easy initial replacement --
# # of substitutions = 0
#   --> output_filepath = /neurd_packages/pytorch_tools/pytorch_tools/parameters_utils.py
# -- harder initial replacement --
# # of substitutions = 0
#   --> output_filepath = /neurd_packages/pytorch_tools/pytorch_tools/parameters_utils.py
#
#
# --- working on package: neuron_morphology_tools ---
# -- easy initial replacement --
# # of substitutions = 0
#   --> output_filepath = /neurd_packages/pytorch_tools/pytorch_tools/parameters_utils.py
# -- harder initial replacement --
# # of substitutions = 0
#   --> output_filepath = /neurd_packages/pytorch_tools/pytorch_tools/parameters_utils.py
# # of multi-line strings = 0
# # of matches (unique = True) = 3
# # of modules replaced = 3
# ----non_pkg_mods_str =
# from collections import OrderedDict
# import torch
#
#
# ----pkg_mods_str =
# #--- from pytorch_tools ---
# from . import tensor_utils as tsu
#
#
# ----own_mod_str =
#
#    --- working on module: /neurd_packages/pytorch_tools/pytorch_tools/preprocessing_utils.py ---
# output_path = /neurd_packages/pytorch_tools/pytorch_tools/preprocessing_utils.py
# Search for package for /neurd_packages/pytorch_tools/pytorch_tools/preprocessing_utils.py
# Matched to /neurd_packages/pytorch_tools/pytorch_tools/
# curr_mod = preprocessing_utils, curr_package_name = pytorch_tools
#
#
# --- working on package: python_tools ---
# -- easy initial replacement --
# # of substitutions = 0
#   --> output_filepath = /neurd_packages/pytorch_tools/pytorch_tools/preprocessing_utils.py
# -- harder initial replacement --
# # of substitutions = 0
#   --> output_filepath = /neurd_packages/pytorch_tools/pytorch_tools/preprocessing_utils.py
#
#
# --- working on package: machine_learning_tools ---
# -- easy initial replacement --
# # of substitutions = 0
#   --> output_filepath = /neurd_packages/pytorch_tools/pytorch_tools/preprocessing_utils.py
# -- harder initial replacement --
# # of substitutions = 0
#   --> output_filepath = /neurd_packages/pytorch_tools/pytorch_tools/preprocessing_utils.py
#
#
# --- working on package: pytorch_tools ---
# -- easy initial replacement --
# # of substitutions = 1
#   --> output_filepath = /neurd_packages/pytorch_tools/pytorch_tools/preprocessing_utils.py
# -- harder initial replacement --
# # of substitutions = 0
#   --> output_filepath = /neurd_packages/pytorch_tools/pytorch_tools/preprocessing_utils.py
# -- easier relative replacement --
# # of substitutions = 1
#   --> output_filepath = /neurd_packages/pytorch_tools/pytorch_tools/preprocessing_utils.py
# -- harder relative replacement --
# # of substitutions = 0
#   --> output_filepath = /neurd_packages/pytorch_tools/pytorch_tools/preprocessing_utils.py
#
#
# --- working on package: graph_tools ---
# -- easy initial replacement --
# # of substitutions = 0
#   --> output_filepath = /neurd_packages/pytorch_tools/pytorch_tools/preprocessing_utils.py
# -- harder initial replacement --
# # of substitutions = 0
#   --> output_filepath = /neurd_packages/pytorch_tools/pytorch_tools/preprocessing_utils.py
#
#
# --- working on package: meshAfterParty ---
# -- easy initial replacement --
# # of substitutions = 0
#   --> output_filepath = /neurd_packages/pytorch_tools/pytorch_tools/preprocessing_utils.py
# -- harder initial replacement --
# # of substitutions = 0
#   --> output_filepath = /neurd_packages/pytorch_tools/pytorch_tools/preprocessing_utils.py
#
#
# --- working on package: neuron_morphology_tools ---
# -- easy initial replacement --
# # of substitutions = 0
#   --> output_filepath = /neurd_packages/pytorch_tools/pytorch_tools/preprocessing_utils.py
# -- harder initial replacement --
# # of substitutions = 0
#   --> output_filepath = /neurd_packages/pytorch_tools/pytorch_tools/preprocessing_utils.py
# # of multi-line strings = 0
# # of matches (unique = True) = 3
# # of modules replaced = 3
# ----non_pkg_mods_str =
# import numpy as np
# import torch
#
#
# ----pkg_mods_str =
#
#
#
# ----own_mod_str =
# from . import preprocessing_utils as preu
#    --- working on module: /neurd_packages/pytorch_tools/pytorch_tools/tensorboard_utils.py ---
# output_path = /neurd_packages/pytorch_tools/pytorch_tools/tensorboard_utils.py
# Search for package for /neurd_packages/pytorch_tools/pytorch_tools/tensorboard_utils.py
# Matched to /neurd_packages/pytorch_tools/pytorch_tools/
# curr_mod = tensorboard_utils, curr_package_name = pytorch_tools
#
#
# --- working on package: python_tools ---
# -- easy initial replacement --
# # of substitutions = 0
#   --> output_filepath = /neurd_packages/pytorch_tools/pytorch_tools/tensorboard_utils.py
# -- harder initial replacement --
# # of substitutions = 0
#   --> output_filepath = /neurd_packages/pytorch_tools/pytorch_tools/tensorboard_utils.py
#
#
# --- working on package: machine_learning_tools ---
# -- easy initial replacement --
# # of substitutions = 0
#   --> output_filepath = /neurd_packages/pytorch_tools/pytorch_tools/tensorboard_utils.py
# -- harder initial replacement --
# # of substitutions = 0
#   --> output_filepath = /neurd_packages/pytorch_tools/pytorch_tools/tensorboard_utils.py
#
#
# --- working on package: pytorch_tools ---
# -- easy initial replacement --
# # of substitutions = 1
#   --> output_filepath = /neurd_packages/pytorch_tools/pytorch_tools/tensorboard_utils.py
# -- harder initial replacement --
# # of substitutions = 0
#   --> output_filepath = /neurd_packages/pytorch_tools/pytorch_tools/tensorboard_utils.py
# -- easier relative replacement --
# # of substitutions = 1
#   --> output_filepath = /neurd_packages/pytorch_tools/pytorch_tools/tensorboard_utils.py
# -- harder relative replacement --
# # of substitutions = 0
#   --> output_filepath = /neurd_packages/pytorch_tools/pytorch_tools/tensorboard_utils.py
#
#
# --- working on package: graph_tools ---
# -- easy initial replacement --
# # of substitutions = 0
#   --> output_filepath = /neurd_packages/pytorch_tools/pytorch_tools/tensorboard_utils.py
# -- harder initial replacement --
# # of substitutions = 0
#   --> output_filepath = /neurd_packages/pytorch_tools/pytorch_tools/tensorboard_utils.py
#
#
# --- working on package: meshAfterParty ---
# -- easy initial replacement --
# # of substitutions = 0
#   --> output_filepath = /neurd_packages/pytorch_tools/pytorch_tools/tensorboard_utils.py
# -- harder initial replacement --
# # of substitutions = 0
#   --> output_filepath = /neurd_packages/pytorch_tools/pytorch_tools/tensorboard_utils.py
#
#
# --- working on package: neuron_morphology_tools ---
# -- easy initial replacement --
# # of substitutions = 0
#   --> output_filepath = /neurd_packages/pytorch_tools/pytorch_tools/tensorboard_utils.py
# -- harder initial replacement --
# # of substitutions = 0
#   --> output_filepath = /neurd_packages/pytorch_tools/pytorch_tools/tensorboard_utils.py
# # of multi-line strings = 1
# # of matches (unique = True) = 5
# # of modules replaced = 5
# ----non_pkg_mods_str =
# from pathlib import Path
# from tensorboard.backend.event_processing.event_file_loader import EventFileLoader
# import os
# import pandas as pd
#
#
# ----pkg_mods_str =
#
#
#
# ----own_mod_str =
# from . import tensorboard_utils as tbu
#    --- working on module: /neurd_packages/pytorch_tools/pytorch_tools/tensor_utils.py ---
# output_path = /neurd_packages/pytorch_tools/pytorch_tools/tensor_utils.py
# Search for package for /neurd_packages/pytorch_tools/pytorch_tools/tensor_utils.py
# Matched to /neurd_packages/pytorch_tools/pytorch_tools/
# curr_mod = tensor_utils, curr_package_name = pytorch_tools
#
#
# --- working on package: python_tools ---
# -- easy initial replacement --
# # of substitutions = 0
#   --> output_filepath = /neurd_packages/pytorch_tools/pytorch_tools/tensor_utils.py
# -- harder initial replacement --
# # of substitutions = 0
#   --> output_filepath = /neurd_packages/pytorch_tools/pytorch_tools/tensor_utils.py
#
#
# --- working on package: machine_learning_tools ---
# -- easy initial replacement --
# # of substitutions = 0
#   --> output_filepath = /neurd_packages/pytorch_tools/pytorch_tools/tensor_utils.py
# -- harder initial replacement --
# # of substitutions = 0
#   --> output_filepath = /neurd_packages/pytorch_tools/pytorch_tools/tensor_utils.py
#
#
# --- working on package: pytorch_tools ---
# -- easy initial replacement --
# # of substitutions = 1
#   --> output_filepath = /neurd_packages/pytorch_tools/pytorch_tools/tensor_utils.py
# -- harder initial replacement --
# # of substitutions = 0
#   --> output_filepath = /neurd_packages/pytorch_tools/pytorch_tools/tensor_utils.py
# -- easier relative replacement --
# # of substitutions = 1
#   --> output_filepath = /neurd_packages/pytorch_tools/pytorch_tools/tensor_utils.py
# -- harder relative replacement --
# # of substitutions = 0
#   --> output_filepath = /neurd_packages/pytorch_tools/pytorch_tools/tensor_utils.py
#
#
# --- working on package: graph_tools ---
# -- easy initial replacement --
# # of substitutions = 0
#   --> output_filepath = /neurd_packages/pytorch_tools/pytorch_tools/tensor_utils.py
# -- harder initial replacement --
# # of substitutions = 0
#   --> output_filepath = /neurd_packages/pytorch_tools/pytorch_tools/tensor_utils.py
#
#
# --- working on package: meshAfterParty ---
# -- easy initial replacement --
# # of substitutions = 0
#   --> output_filepath = /neurd_packages/pytorch_tools/pytorch_tools/tensor_utils.py
# -- harder initial replacement --
# # of substitutions = 0
#   --> output_filepath = /neurd_packages/pytorch_tools/pytorch_tools/tensor_utils.py
#
#
# --- working on package: neuron_morphology_tools ---
# -- easy initial replacement --
# # of substitutions = 0
#   --> output_filepath = /neurd_packages/pytorch_tools/pytorch_tools/tensor_utils.py
# -- harder initial replacement --
# # of substitutions = 0
#   --> output_filepath = /neurd_packages/pytorch_tools/pytorch_tools/tensor_utils.py
# # of multi-line strings = 0
# # of matches (unique = True) = 2
# # of modules replaced = 2
# ----non_pkg_mods_str =
# import torch
#
#
# ----pkg_mods_str =
#
#
#
# ----own_mod_str =
# from . import tensor_utils as tenu
#    --- working on module: /neurd_packages/pytorch_tools/pytorch_tools/torch_display_utils.py ---
# output_path = /neurd_packages/pytorch_tools/pytorch_tools/torch_display_utils.py
# Search for package for /neurd_packages/pytorch_tools/pytorch_tools/torch_display_utils.py
# Matched to /neurd_packages/pytorch_tools/pytorch_tools/
# curr_mod = torch_display_utils, curr_package_name = pytorch_tools
#
#
# --- working on package: python_tools ---
# -- easy initial replacement --
# # of substitutions = 0
#   --> output_filepath = /neurd_packages/pytorch_tools/pytorch_tools/torch_display_utils.py
# -- harder initial replacement --
# # of substitutions = 0
#   --> output_filepath = /neurd_packages/pytorch_tools/pytorch_tools/torch_display_utils.py
#
#
# --- working on package: machine_learning_tools ---
# -- easy initial replacement --
# # of substitutions = 0
#   --> output_filepath = /neurd_packages/pytorch_tools/pytorch_tools/torch_display_utils.py
# -- harder initial replacement --
# # of substitutions = 0
#   --> output_filepath = /neurd_packages/pytorch_tools/pytorch_tools/torch_display_utils.py
#
#
# --- working on package: pytorch_tools ---
# -- easy initial replacement --
# # of substitutions = 0
#   --> output_filepath = /neurd_packages/pytorch_tools/pytorch_tools/torch_display_utils.py
# -- harder initial replacement --
# # of substitutions = 0
#   --> output_filepath = /neurd_packages/pytorch_tools/pytorch_tools/torch_display_utils.py
# -- easier relative replacement --
# # of substitutions = 0
#   --> output_filepath = /neurd_packages/pytorch_tools/pytorch_tools/torch_display_utils.py
# -- harder relative replacement --
# # of substitutions = 0
#   --> output_filepath = /neurd_packages/pytorch_tools/pytorch_tools/torch_display_utils.py
#
#
# --- working on package: graph_tools ---
# -- easy initial replacement --
# # of substitutions = 0
#   --> output_filepath = /neurd_packages/pytorch_tools/pytorch_tools/torch_display_utils.py
# -- harder initial replacement --
# # of substitutions = 0
#   --> output_filepath = /neurd_packages/pytorch_tools/pytorch_tools/torch_display_utils.py
#
#
# --- working on package: meshAfterParty ---
# -- easy initial replacement --
# # of substitutions = 0
#   --> output_filepath = /neurd_packages/pytorch_tools/pytorch_tools/torch_display_utils.py
# -- harder initial replacement --
# # of substitutions = 0
#   --> output_filepath = /neurd_packages/pytorch_tools/pytorch_tools/torch_display_utils.py
#
#
# --- working on package: neuron_morphology_tools ---
# -- easy initial replacement --
# # of substitutions = 0
#   --> output_filepath = /neurd_packages/pytorch_tools/pytorch_tools/torch_display_utils.py
# -- harder initial replacement --
# # of substitutions = 0
#   --> output_filepath = /neurd_packages/pytorch_tools/pytorch_tools/torch_display_utils.py
# # of multi-line strings = 0
# # of matches (unique = True) = 1
# # of modules replaced = 1
# ----non_pkg_mods_str =
# import torch
#
#
# ----pkg_mods_str =
#
#
#
# ----own_mod_str =
#
#    --- working on module: /neurd_packages/pytorch_tools/pytorch_tools/training_layer_utils.py ---
# output_path = /neurd_packages/pytorch_tools/pytorch_tools/training_layer_utils.py
# Search for package for /neurd_packages/pytorch_tools/pytorch_tools/training_layer_utils.py
# Matched to /neurd_packages/pytorch_tools/pytorch_tools/
# curr_mod = training_layer_utils, curr_package_name = pytorch_tools
#
#
# --- working on package: python_tools ---
# -- easy initial replacement --
# # of substitutions = 0
#   --> output_filepath = /neurd_packages/pytorch_tools/pytorch_tools/training_layer_utils.py
# -- harder initial replacement --
# # of substitutions = 0
#   --> output_filepath = /neurd_packages/pytorch_tools/pytorch_tools/training_layer_utils.py
#
#
# --- working on package: machine_learning_tools ---
# -- easy initial replacement --
# # of substitutions = 0
#   --> output_filepath = /neurd_packages/pytorch_tools/pytorch_tools/training_layer_utils.py
# -- harder initial replacement --
# # of substitutions = 0
#   --> output_filepath = /neurd_packages/pytorch_tools/pytorch_tools/training_layer_utils.py
#
#
# --- working on package: pytorch_tools ---
# -- easy initial replacement --
# # of substitutions = 0
#   --> output_filepath = /neurd_packages/pytorch_tools/pytorch_tools/training_layer_utils.py
# -- harder initial replacement --
# # of substitutions = 0
#   --> output_filepath = /neurd_packages/pytorch_tools/pytorch_tools/training_layer_utils.py
# -- easier relative replacement --
# # of substitutions = 0
#   --> output_filepath = /neurd_packages/pytorch_tools/pytorch_tools/training_layer_utils.py
# -- harder relative replacement --
# # of substitutions = 0
#   --> output_filepath = /neurd_packages/pytorch_tools/pytorch_tools/training_layer_utils.py
#
#
# --- working on package: graph_tools ---
# -- easy initial replacement --
# # of substitutions = 0
#   --> output_filepath = /neurd_packages/pytorch_tools/pytorch_tools/training_layer_utils.py
# -- harder initial replacement --
# # of substitutions = 0
#   --> output_filepath = /neurd_packages/pytorch_tools/pytorch_tools/training_layer_utils.py
#
#
# --- working on package: meshAfterParty ---
# -- easy initial replacement --
# # of substitutions = 0
#   --> output_filepath = /neurd_packages/pytorch_tools/pytorch_tools/training_layer_utils.py
# -- harder initial replacement --
# # of substitutions = 0
#   --> output_filepath = /neurd_packages/pytorch_tools/pytorch_tools/training_layer_utils.py
#
#
# --- working on package: neuron_morphology_tools ---
# -- easy initial replacement --
# # of substitutions = 0
#   --> output_filepath = /neurd_packages/pytorch_tools/pytorch_tools/training_layer_utils.py
# -- harder initial replacement --
# # of substitutions = 0
#   --> output_filepath = /neurd_packages/pytorch_tools/pytorch_tools/training_layer_utils.py
# # of multi-line strings = 1
# # of matches (unique = True) = 0
# # of modules replaced = 1
# ----non_pkg_mods_str =
#
#
#
# ----pkg_mods_str =
#
#
#
# ----own_mod_str =
#
#    --- working on module: /neurd_packages/pytorch_tools/pytorch_tools/train_test_geometric_utils.py ---
# output_path = /neurd_packages/pytorch_tools/pytorch_tools/train_test_geometric_utils.py
# Search for package for /neurd_packages/pytorch_tools/pytorch_tools/train_test_geometric_utils.py
# Matched to /neurd_packages/pytorch_tools/pytorch_tools/
# curr_mod = train_test_geometric_utils, curr_package_name = pytorch_tools
#
#
# --- working on package: python_tools ---
# -- easy initial replacement --
# # of substitutions = 2
#   --> output_filepath = /neurd_packages/pytorch_tools/pytorch_tools/train_test_geometric_utils.py
# -- harder initial replacement --
# # of substitutions = 0
#   --> output_filepath = /neurd_packages/pytorch_tools/pytorch_tools/train_test_geometric_utils.py
#
#
# --- working on package: machine_learning_tools ---
# -- easy initial replacement --
# # of substitutions = 0
#   --> output_filepath = /neurd_packages/pytorch_tools/pytorch_tools/train_test_geometric_utils.py
# -- harder initial replacement --
# # of substitutions = 0
#   --> output_filepath = /neurd_packages/pytorch_tools/pytorch_tools/train_test_geometric_utils.py
#
#
# --- working on package: pytorch_tools ---
# -- easy initial replacement --
# # of substitutions = 5
#   --> output_filepath = /neurd_packages/pytorch_tools/pytorch_tools/train_test_geometric_utils.py
# -- harder initial replacement --
# # of substitutions = 0
#   --> output_filepath = /neurd_packages/pytorch_tools/pytorch_tools/train_test_geometric_utils.py
# -- easier relative replacement --
# # of substitutions = 5
#   --> output_filepath = /neurd_packages/pytorch_tools/pytorch_tools/train_test_geometric_utils.py
# -- harder relative replacement --
# # of substitutions = 0
#   --> output_filepath = /neurd_packages/pytorch_tools/pytorch_tools/train_test_geometric_utils.py
#
#
# --- working on package: graph_tools ---
# -- easy initial replacement --
# # of substitutions = 0
#   --> output_filepath = /neurd_packages/pytorch_tools/pytorch_tools/train_test_geometric_utils.py
# -- harder initial replacement --
# # of substitutions = 0
#   --> output_filepath = /neurd_packages/pytorch_tools/pytorch_tools/train_test_geometric_utils.py
#
#
# --- working on package: meshAfterParty ---
# -- easy initial replacement --
# # of substitutions = 0
#   --> output_filepath = /neurd_packages/pytorch_tools/pytorch_tools/train_test_geometric_utils.py
# -- harder initial replacement --
# # of substitutions = 0
#   --> output_filepath = /neurd_packages/pytorch_tools/pytorch_tools/train_test_geometric_utils.py
#
#
# --- working on package: neuron_morphology_tools ---
# -- easy initial replacement --
# # of substitutions = 0
#   --> output_filepath = /neurd_packages/pytorch_tools/pytorch_tools/train_test_geometric_utils.py
# -- harder initial replacement --
# # of substitutions = 0
#   --> output_filepath = /neurd_packages/pytorch_tools/pytorch_tools/train_test_geometric_utils.py
# # of multi-line strings = 1
# # of matches (unique = True) = 11
# # of modules replaced = 11
# ----non_pkg_mods_str =
# import numpy as np
# import pandas as pd
# import torch
# import torch.nn.functional as F
#
#
# ----pkg_mods_str =
# #--- from pytorch_tools ---
# from . import data_augmentation_utils as dau
# from . import evaluation_utils as evu
# from . import parameters_utils as paru
# from . import tensor_utils as tenu
#
# #--- from python_tools ---
# from python_tools import general_utils as gu
# from python_tools import pandas_utils as pu
#
#
# ----own_mod_str =
# from . import train_test_geometric_utils as ttu
#    --- working on module: /neurd_packages/pytorch_tools/pytorch_tools/xai_geometric_utils.py ---
# output_path = /neurd_packages/pytorch_tools/pytorch_tools/xai_geometric_utils.py
# Search for package for /neurd_packages/pytorch_tools/pytorch_tools/xai_geometric_utils.py
# Matched to /neurd_packages/pytorch_tools/pytorch_tools/
# curr_mod = xai_geometric_utils, curr_package_name = pytorch_tools
#
#
# --- working on package: python_tools ---
# -- easy initial replacement --
# # of substitutions = 0
#   --> output_filepath = /neurd_packages/pytorch_tools/pytorch_tools/xai_geometric_utils.py
# -- harder initial replacement --
# # of substitutions = 0
#   --> output_filepath = /neurd_packages/pytorch_tools/pytorch_tools/xai_geometric_utils.py
#
#
# --- working on package: machine_learning_tools ---
# -- easy initial replacement --
# # of substitutions = 0
#   --> output_filepath = /neurd_packages/pytorch_tools/pytorch_tools/xai_geometric_utils.py
# -- harder initial replacement --
# # of substitutions = 0
#   --> output_filepath = /neurd_packages/pytorch_tools/pytorch_tools/xai_geometric_utils.py
#
#
# --- working on package: pytorch_tools ---
# -- easy initial replacement --
# # of substitutions = 0
#   --> output_filepath = /neurd_packages/pytorch_tools/pytorch_tools/xai_geometric_utils.py
# -- harder initial replacement --
# # of substitutions = 0
#   --> output_filepath = /neurd_packages/pytorch_tools/pytorch_tools/xai_geometric_utils.py
# -- easier relative replacement --
# # of substitutions = 0
#   --> output_filepath = /neurd_packages/pytorch_tools/pytorch_tools/xai_geometric_utils.py
# -- harder relative replacement --
# # of substitutions = 0
#   --> output_filepath = /neurd_packages/pytorch_tools/pytorch_tools/xai_geometric_utils.py
#
#
# --- working on package: graph_tools ---
# -- easy initial replacement --
# # of substitutions = 0
#   --> output_filepath = /neurd_packages/pytorch_tools/pytorch_tools/xai_geometric_utils.py
# -- harder initial replacement --
# # of substitutions = 0
#   --> output_filepath = /neurd_packages/pytorch_tools/pytorch_tools/xai_geometric_utils.py
#
#
# --- working on package: meshAfterParty ---
# -- easy initial replacement --
# # of substitutions = 0
#   --> output_filepath = /neurd_packages/pytorch_tools/pytorch_tools/xai_geometric_utils.py
# -- harder initial replacement --
# # of substitutions = 0
#   --> output_filepath = /neurd_packages/pytorch_tools/pytorch_tools/xai_geometric_utils.py
#
#
# --- working on package: neuron_morphology_tools ---
# -- easy initial replacement --
# # of substitutions = 0
#   --> output_filepath = /neurd_packages/pytorch_tools/pytorch_tools/xai_geometric_utils.py
# -- harder initial replacement --
# # of substitutions = 0
#   --> output_filepath = /neurd_packages/pytorch_tools/pytorch_tools/xai_geometric_utils.py
# # of multi-line strings = 1
# # of matches (unique = True) = 0
# # of modules replaced = 1
# ----non_pkg_mods_str =
#
#
#
# ----pkg_mods_str =
#
#
#
# ----own_mod_str =

# %% [markdown]
# # Cleaning all other packages for this name

# %%
pku.prefix_module_imports_in_files(
    #filepaths = ["/neurd_packages/meshAfterParty/meshAfterParty/dataInterface.py"],
    modules_directory=directory,
    filepaths_directory = pku.user_packages,
    overwrite_file = True,
    verbose = True,
    debug_files = False,
)
# Out:
# skipping filepath directory /neurd_packages/pytorch_tools/pytorch_tools
# --- Working on file: /neurd_packages/python_tools/python_tools/algorithms_utils.py
# --Getting files from /neurd_packages/pytorch_tools/pytorch_tools
# # of py files = 20
# # of substitutions = 0
#   --> output_filepath = /neurd_packages/python_tools/python_tools/algorithms_utils.py
# --- Working on file: /neurd_packages/python_tools/python_tools/argparse_utils.py
# --Getting files from /neurd_packages/pytorch_tools/pytorch_tools
# # of py files = 20
# # of substitutions = 0
#   --> output_filepath = /neurd_packages/python_tools/python_tools/argparse_utils.py
# --- Working on file: /neurd_packages/python_tools/python_tools/dataclass_utils.py
# --Getting files from /neurd_packages/pytorch_tools/pytorch_tools
# # of py files = 20
# # of substitutions = 0
#   --> output_filepath = /neurd_packages/python_tools/python_tools/dataclass_utils.py
# --- Working on file: /neurd_packages/python_tools/python_tools/data_struct_utils.py
# --Getting files from /neurd_packages/pytorch_tools/pytorch_tools
# # of py files = 20
# # of substitutions = 0
#   --> output_filepath = /neurd_packages/python_tools/python_tools/data_struct_utils.py
# --- Working on file: /neurd_packages/python_tools/python_tools/dict_utils.py
# --Getting files from /neurd_packages/pytorch_tools/pytorch_tools
# # of py files = 20
# # of substitutions = 0
#   --> output_filepath = /neurd_packages/python_tools/python_tools/dict_utils.py
# --- Working on file: /neurd_packages/python_tools/python_tools/dj_utils.py
# --Getting files from /neurd_packages/pytorch_tools/pytorch_tools
# # of py files = 20
# # of substitutions = 0
#   --> output_filepath = /neurd_packages/python_tools/python_tools/dj_utils.py
# --- Working on file: /neurd_packages/python_tools/python_tools/enum_utils.py
# --Getting files from /neurd_packages/pytorch_tools/pytorch_tools
# # of py files = 20
# # of substitutions = 0
#   --> output_filepath = /neurd_packages/python_tools/python_tools/enum_utils.py
# --- Working on file: /neurd_packages/python_tools/python_tools/file_utils.py
# --Getting files from /neurd_packages/pytorch_tools/pytorch_tools
# # of py files = 20
# # of substitutions = 0
#   --> output_filepath = /neurd_packages/python_tools/python_tools/file_utils.py
# --- Working on file: /neurd_packages/python_tools/python_tools/filtering_utils.py
# --Getting files from /neurd_packages/pytorch_tools/pytorch_tools
# # of py files = 20
# # of substitutions = 0
#   --> output_filepath = /neurd_packages/python_tools/python_tools/filtering_utils.py
# --- Working on file: /neurd_packages/python_tools/python_tools/function_utils.py
# --Getting files from /neurd_packages/pytorch_tools/pytorch_tools
# # of py files = 20
# # of substitutions = 0
#   --> output_filepath = /neurd_packages/python_tools/python_tools/function_utils.py
# --- Working on file: /neurd_packages/python_tools/python_tools/general_utils.py
# --Getting files from /neurd_packages/pytorch_tools/pytorch_tools
# # of py files = 20
# # of substitutions = 0
#   --> output_filepath = /neurd_packages/python_tools/python_tools/general_utils.py
# --- Working on file: /neurd_packages/python_tools/python_tools/hash_utils.py
# --Getting files from /neurd_packages/pytorch_tools/pytorch_tools
# # of py files = 20
# # of substitutions = 0
#   --> output_filepath = /neurd_packages/python_tools/python_tools/hash_utils.py
# --- Working on file: /neurd_packages/python_tools/python_tools/inspect_utils.py
# --Getting files from /neurd_packages/pytorch_tools/pytorch_tools
# # of py files = 20
# # of substitutions = 0
#   --> output_filepath = /neurd_packages/python_tools/python_tools/inspect_utils.py
# --- Working on file: /neurd_packages/python_tools/python_tools/ipyvolume_movie_utils.py
# --Getting files from /neurd_packages/pytorch_tools/pytorch_tools
# # of py files = 20
# # of substitutions = 0
#   --> output_filepath = /neurd_packages/python_tools/python_tools/ipyvolume_movie_utils.py
# --- Working on file: /neurd_packages/python_tools/python_tools/ipyvolume_utils.py
# --Getting files from /neurd_packages/pytorch_tools/pytorch_tools
# # of py files = 20
# # of substitutions = 0
#   --> output_filepath = /neurd_packages/python_tools/python_tools/ipyvolume_utils.py
# --- Working on file: /neurd_packages/python_tools/python_tools/json_utils.py
# --Getting files from /neurd_packages/pytorch_tools/pytorch_tools
# # of py files = 20
# # of substitutions = 0
#   --> output_filepath = /neurd_packages/python_tools/python_tools/json_utils.py
# --- Working on file: /neurd_packages/python_tools/python_tools/linalg_utils.py
# --Getting files from /neurd_packages/pytorch_tools/pytorch_tools
# # of py files = 20
# # of substitutions = 0
#   --> output_filepath = /neurd_packages/python_tools/python_tools/linalg_utils.py
# --- Working on file: /neurd_packages/python_tools/python_tools/logging_utils.py
# --Getting files from /neurd_packages/pytorch_tools/pytorch_tools
# # of py files = 20
# # of substitutions = 0
#   --> output_filepath = /neurd_packages/python_tools/python_tools/logging_utils.py
# --- Working on file: /neurd_packages/python_tools/python_tools/matlab_utils.py
# --Getting files from /neurd_packages/pytorch_tools/pytorch_tools
# # of py files = 20
# # of substitutions = 0
#   --> output_filepath = /neurd_packages/python_tools/python_tools/matlab_utils.py
# --- Working on file: /neurd_packages/python_tools/python_tools/matplotlib_utils.py
# --Getting files from /neurd_packages/pytorch_tools/pytorch_tools
# # of py files = 20
# # of substitutions = 0
#   --> output_filepath = /neurd_packages/python_tools/python_tools/matplotlib_utils.py
# --- Working on file: /neurd_packages/python_tools/python_tools/mesh_utils.py
# --Getting files from /neurd_packages/pytorch_tools/pytorch_tools
# # of py files = 20
# # of substitutions = 0
#   --> output_filepath = /neurd_packages/python_tools/python_tools/mesh_utils.py
# --- Working on file: /neurd_packages/python_tools/python_tools/module_utils.py
# --Getting files from /neurd_packages/pytorch_tools/pytorch_tools
# # of py files = 20
# # of substitutions = 0
#   --> output_filepath = /neurd_packages/python_tools/python_tools/module_utils.py
# --- Working on file: /neurd_packages/python_tools/python_tools/networkx_utils.py
# --Getting files from /neurd_packages/pytorch_tools/pytorch_tools
# # of py files = 20
# # of substitutions = 0
#   --> output_filepath = /neurd_packages/python_tools/python_tools/networkx_utils.py
# --- Working on file: /neurd_packages/python_tools/python_tools/numpy_utils.py
# --Getting files from /neurd_packages/pytorch_tools/pytorch_tools
# # of py files = 20
# # of substitutions = 0
#   --> output_filepath = /neurd_packages/python_tools/python_tools/numpy_utils.py
# --- Working on file: /neurd_packages/python_tools/python_tools/package_utils.py
# --Getting files from /neurd_packages/pytorch_tools/pytorch_tools
# # of py files = 20
# # of substitutions = 0
#   --> output_filepath = /neurd_packages/python_tools/python_tools/package_utils.py
# --- Working on file: /neurd_packages/python_tools/python_tools/pandas_utils.py
# --Getting files from /neurd_packages/pytorch_tools/pytorch_tools
# # of py files = 20
# # of substitutions = 0
#   --> output_filepath = /neurd_packages/python_tools/python_tools/pandas_utils.py
# --- Working on file: /neurd_packages/python_tools/python_tools/pathlib_utils.py
# --Getting files from /neurd_packages/pytorch_tools/pytorch_tools
# # of py files = 20
# # of substitutions = 0
#   --> output_filepath = /neurd_packages/python_tools/python_tools/pathlib_utils.py
# --- Working on file: /neurd_packages/python_tools/python_tools/pretty_print_confusion_matrix.py
# --Getting files from /neurd_packages/pytorch_tools/pytorch_tools
# # of py files = 20
# # of substitutions = 0
#   --> output_filepath = /neurd_packages/python_tools/python_tools/pretty_print_confusion_matrix.py
# --- Working on file: /neurd_packages/python_tools/python_tools/pydantic_utls.py
# --Getting files from /neurd_packages/pytorch_tools/pytorch_tools
# # of py files = 20
# # of substitutions = 0
#   --> output_filepath = /neurd_packages/python_tools/python_tools/pydantic_utls.py
# --- Working on file: /neurd_packages/python_tools/python_tools/regex_utils.py
# --Getting files from /neurd_packages/pytorch_tools/pytorch_tools
# # of py files = 20
# # of substitutions = 0
#   --> output_filepath = /neurd_packages/python_tools/python_tools/regex_utils.py
# --- Working on file: /neurd_packages/python_tools/python_tools/requirement_utils.py
# --Getting files from /neurd_packages/pytorch_tools/pytorch_tools
# # of py files = 20
# # of substitutions = 0
#   --> output_filepath = /neurd_packages/python_tools/python_tools/requirement_utils.py
# --- Working on file: /neurd_packages/python_tools/python_tools/scipy_utils.py
# --Getting files from /neurd_packages/pytorch_tools/pytorch_tools
# # of py files = 20
# # of substitutions = 0
#   --> output_filepath = /neurd_packages/python_tools/python_tools/scipy_utils.py
# --- Working on file: /neurd_packages/python_tools/python_tools/seaborn_utils.py
# --Getting files from /neurd_packages/pytorch_tools/pytorch_tools
# # of py files = 20
# # of substitutions = 0
#   --> output_filepath = /neurd_packages/python_tools/python_tools/seaborn_utils.py
# --- Working on file: /neurd_packages/python_tools/python_tools/setup_py_utils.py
# --Getting files from /neurd_packages/pytorch_tools/pytorch_tools
# # of py files = 20
# # of substitutions = 0
#   --> output_filepath = /neurd_packages/python_tools/python_tools/setup_py_utils.py
# --- Working on file: /neurd_packages/python_tools/python_tools/statistics_utils.py
# --Getting files from /neurd_packages/pytorch_tools/pytorch_tools
# # of py files = 20
# # of substitutions = 0
#   --> output_filepath = /neurd_packages/python_tools/python_tools/statistics_utils.py
# --- Working on file: /neurd_packages/python_tools/python_tools/statistics_visualizations.py
# --Getting files from /neurd_packages/pytorch_tools/pytorch_tools
# # of py files = 20
# # of substitutions = 0
#   --> output_filepath = /neurd_packages/python_tools/python_tools/statistics_visualizations.py
# --- Working on file: /neurd_packages/python_tools/python_tools/string_utils.py
# --Getting files from /neurd_packages/pytorch_tools/pytorch_tools
# # of py files = 20
# # of substitutions = 0
#   --> output_filepath = /neurd_packages/python_tools/python_tools/string_utils.py
# --- Working on file: /neurd_packages/python_tools/python_tools/system_utils.py
# --Getting files from /neurd_packages/pytorch_tools/pytorch_tools
# # of py files = 20
# # of substitutions = 0
#   --> output_filepath = /neurd_packages/python_tools/python_tools/system_utils.py
# --- Working on file: /neurd_packages/python_tools/python_tools/tqdm_utils.py
# --Getting files from /neurd_packages/pytorch_tools/pytorch_tools
# # of py files = 20
# # of substitutions = 0
#   --> output_filepath = /neurd_packages/python_tools/python_tools/tqdm_utils.py
# --- Working on file: /neurd_packages/python_tools/python_tools/typeing_utils.py
# --Getting files from /neurd_packages/pytorch_tools/pytorch_tools
# # of py files = 20
# # of substitutions = 0
#   --> output_filepath = /neurd_packages/python_tools/python_tools/typeing_utils.py
# --- Working on file: /neurd_packages/python_tools/python_tools/widget_utils.py
# --Getting files from /neurd_packages/pytorch_tools/pytorch_tools
# # of py files = 20
# # of substitutions = 0
#   --> output_filepath = /neurd_packages/python_tools/python_tools/widget_utils.py
# --- Working on file: /neurd_packages/python_tools/python_tools/__init__.py
# --Getting files from /neurd_packages/pytorch_tools/pytorch_tools
# # of py files = 20
# # of substitutions = 0
#   --> output_filepath = /neurd_packages/python_tools/python_tools/__init__.py
# --- Working on file: /neurd_packages/machine_learning_tools/machine_learning_tools/clustering_ml.py
# --Getting files from /neurd_packages/pytorch_tools/pytorch_tools
# # of py files = 20
# # of substitutions = 0
#   --> output_filepath = /neurd_packages/machine_learning_tools/machine_learning_tools/clustering_ml.py
# --- Working on file: /neurd_packages/machine_learning_tools/machine_learning_tools/data_annotation_utils.py
# --Getting files from /neurd_packages/pytorch_tools/pytorch_tools
# # of py files = 20
# # of substitutions = 0
#   --> output_filepath = /neurd_packages/machine_learning_tools/machine_learning_tools/data_annotation_utils.py
# --- Working on file: /neurd_packages/machine_learning_tools/machine_learning_tools/data_input_utils.py
# --Getting files from /neurd_packages/pytorch_tools/pytorch_tools
# # of py files = 20
# # of substitutions = 0
#   --> output_filepath = /neurd_packages/machine_learning_tools/machine_learning_tools/data_input_utils.py
# --- Working on file: /neurd_packages/machine_learning_tools/machine_learning_tools/dimensionality_reduction_ml.py
# --Getting files from /neurd_packages/pytorch_tools/pytorch_tools
# # of py files = 20
# # of substitutions = 0
#   --> output_filepath = /neurd_packages/machine_learning_tools/machine_learning_tools/dimensionality_reduction_ml.py
# --- Working on file: /neurd_packages/machine_learning_tools/machine_learning_tools/dimensionality_reduction_utils.py
# --Getting files from /neurd_packages/pytorch_tools/pytorch_tools
# # of py files = 20
# # of substitutions = 0
#   --> output_filepath = /neurd_packages/machine_learning_tools/machine_learning_tools/dimensionality_reduction_utils.py
# --- Working on file: /neurd_packages/machine_learning_tools/machine_learning_tools/evaluation_metrics_utils.py
# --Getting files from /neurd_packages/pytorch_tools/pytorch_tools
# # of py files = 20
# # of substitutions = 0
#   --> output_filepath = /neurd_packages/machine_learning_tools/machine_learning_tools/evaluation_metrics_utils.py
# --- Working on file: /neurd_packages/machine_learning_tools/machine_learning_tools/feature_selection_utils.py
# --Getting files from /neurd_packages/pytorch_tools/pytorch_tools
# # of py files = 20
# # of substitutions = 0
#   --> output_filepath = /neurd_packages/machine_learning_tools/machine_learning_tools/feature_selection_utils.py
# --- Working on file: /neurd_packages/machine_learning_tools/machine_learning_tools/hyperparameters_ml.py
# --Getting files from /neurd_packages/pytorch_tools/pytorch_tools
# # of py files = 20
# # of substitutions = 0
#   --> output_filepath = /neurd_packages/machine_learning_tools/machine_learning_tools/hyperparameters_ml.py
# --- Working on file: /neurd_packages/machine_learning_tools/machine_learning_tools/matplotlib_ml.py
# --Getting files from /neurd_packages/pytorch_tools/pytorch_tools
# # of py files = 20
# # of substitutions = 0
#   --> output_filepath = /neurd_packages/machine_learning_tools/machine_learning_tools/matplotlib_ml.py
# --- Working on file: /neurd_packages/machine_learning_tools/machine_learning_tools/numpy_ml.py
# --Getting files from /neurd_packages/pytorch_tools/pytorch_tools
# # of py files = 20
# # of substitutions = 0
#   --> output_filepath = /neurd_packages/machine_learning_tools/machine_learning_tools/numpy_ml.py
# --- Working on file: /neurd_packages/machine_learning_tools/machine_learning_tools/pandas_ml.py
# --Getting files from /neurd_packages/pytorch_tools/pytorch_tools
# # of py files = 20
# # of substitutions = 0
#   --> output_filepath = /neurd_packages/machine_learning_tools/machine_learning_tools/pandas_ml.py
# --- Working on file: /neurd_packages/machine_learning_tools/machine_learning_tools/preprocessing_ml.py
# --Getting files from /neurd_packages/pytorch_tools/pytorch_tools
# # of py files = 20
# # of substitutions = 0
#   --> output_filepath = /neurd_packages/machine_learning_tools/machine_learning_tools/preprocessing_ml.py
# --- Working on file: /neurd_packages/machine_learning_tools/machine_learning_tools/seaborn_ml.py
# --Getting files from /neurd_packages/pytorch_tools/pytorch_tools
# # of py files = 20
# # of substitutions = 0
#   --> output_filepath = /neurd_packages/machine_learning_tools/machine_learning_tools/seaborn_ml.py
# --- Working on file: /neurd_packages/machine_learning_tools/machine_learning_tools/sklearn_models.py
# --Getting files from /neurd_packages/pytorch_tools/pytorch_tools
# # of py files = 20
# # of substitutions = 0
#   --> output_filepath = /neurd_packages/machine_learning_tools/machine_learning_tools/sklearn_models.py
# --- Working on file: /neurd_packages/machine_learning_tools/machine_learning_tools/sklearn_utils.py
# --Getting files from /neurd_packages/pytorch_tools/pytorch_tools
# # of py files = 20
# # of substitutions = 0
#   --> output_filepath = /neurd_packages/machine_learning_tools/machine_learning_tools/sklearn_utils.py
# --- Working on file: /neurd_packages/machine_learning_tools/machine_learning_tools/statsmodels_utils.py
# --Getting files from /neurd_packages/pytorch_tools/pytorch_tools
# # of py files = 20
# # of substitutions = 0
#   --> output_filepath = /neurd_packages/machine_learning_tools/machine_learning_tools/statsmodels_utils.py
# --- Working on file: /neurd_packages/machine_learning_tools/machine_learning_tools/visualizations_ml.py
# --Getting files from /neurd_packages/pytorch_tools/pytorch_tools
# # of py files = 20
# # of substitutions = 0
#   --> output_filepath = /neurd_packages/machine_learning_tools/machine_learning_tools/visualizations_ml.py
# --- Working on file: /neurd_packages/machine_learning_tools/machine_learning_tools/__init__.py
# --Getting files from /neurd_packages/pytorch_tools/pytorch_tools
# # of py files = 20
# # of substitutions = 0
#   --> output_filepath = /neurd_packages/machine_learning_tools/machine_learning_tools/__init__.py
# --- Working on file: /neurd_packages/graph_tools/graph_tools/epidemics_utils.py
# --Getting files from /neurd_packages/pytorch_tools/pytorch_tools
# # of py files = 20
# # of substitutions = 0
#   --> output_filepath = /neurd_packages/graph_tools/graph_tools/epidemics_utils.py
# --- Working on file: /neurd_packages/graph_tools/graph_tools/graph_path_utils.py
# --Getting files from /neurd_packages/pytorch_tools/pytorch_tools
# # of py files = 20
# # of substitutions = 0
#   --> output_filepath = /neurd_packages/graph_tools/graph_tools/graph_path_utils.py
# --- Working on file: /neurd_packages/graph_tools/graph_tools/graph_preprocessing.py
# --Getting files from /neurd_packages/pytorch_tools/pytorch_tools
# # of py files = 20
# # of substitutions = 0
#   --> output_filepath = /neurd_packages/graph_tools/graph_tools/graph_preprocessing.py
# --- Working on file: /neurd_packages/graph_tools/graph_tools/graph_statistics.py
# --Getting files from /neurd_packages/pytorch_tools/pytorch_tools
# # of py files = 20
# # of substitutions = 0
#   --> output_filepath = /neurd_packages/graph_tools/graph_tools/graph_statistics.py
# --- Working on file: /neurd_packages/graph_tools/graph_tools/graph_visualizations.py
# --Getting files from /neurd_packages/pytorch_tools/pytorch_tools
# # of py files = 20
# # of substitutions = 0
#   --> output_filepath = /neurd_packages/graph_tools/graph_tools/graph_visualizations.py
# --- Working on file: /neurd_packages/graph_tools/graph_tools/netsci_utils.py
# --Getting files from /neurd_packages/pytorch_tools/pytorch_tools
# # of py files = 20
# # of substitutions = 0
#   --> output_filepath = /neurd_packages/graph_tools/graph_tools/netsci_utils.py
# --- Working on file: /neurd_packages/graph_tools/graph_tools/null_models.py
# --Getting files from /neurd_packages/pytorch_tools/pytorch_tools
# # of py files = 20
# # of substitutions = 0
#   --> output_filepath = /neurd_packages/graph_tools/graph_tools/null_models.py
# --- Working on file: /neurd_packages/graph_tools/graph_tools/__init__.py
# --Getting files from /neurd_packages/pytorch_tools/pytorch_tools
# # of py files = 20
# # of substitutions = 0
#   --> output_filepath = /neurd_packages/graph_tools/graph_tools/__init__.py
# --- Working on file: /neurd_packages/meshAfterParty/meshAfterParty/ais_utils.py
# --Getting files from /neurd_packages/pytorch_tools/pytorch_tools
# # of py files = 20
# # of substitutions = 0
#   --> output_filepath = /neurd_packages/meshAfterParty/meshAfterParty/ais_utils.py
# --- Working on file: /neurd_packages/meshAfterParty/meshAfterParty/allen_proofreading_utils.py
# --Getting files from /neurd_packages/pytorch_tools/pytorch_tools
# # of py files = 20
# # of substitutions = 0
#   --> output_filepath = /neurd_packages/meshAfterParty/meshAfterParty/allen_proofreading_utils.py
# --- Working on file: /neurd_packages/meshAfterParty/meshAfterParty/allen_utils.py
# --Getting files from /neurd_packages/pytorch_tools/pytorch_tools
# # of py files = 20
# # of substitutions = 0
#   --> output_filepath = /neurd_packages/meshAfterParty/meshAfterParty/allen_utils.py
# --- Working on file: /neurd_packages/meshAfterParty/meshAfterParty/analysis_snippets.py
# --Getting files from /neurd_packages/pytorch_tools/pytorch_tools
# # of py files = 20
# # of substitutions = 0
#   --> output_filepath = /neurd_packages/meshAfterParty/meshAfterParty/analysis_snippets.py
# --- Working on file: /neurd_packages/meshAfterParty/meshAfterParty/apical_utils.py
# --Getting files from /neurd_packages/pytorch_tools/pytorch_tools
# # of py files = 20
# # of substitutions = 0
#   --> output_filepath = /neurd_packages/meshAfterParty/meshAfterParty/apical_utils.py
# --- Working on file: /neurd_packages/meshAfterParty/meshAfterParty/apl_proofreading_utils.py
# --Getting files from /neurd_packages/pytorch_tools/pytorch_tools
# # of py files = 20
# # of substitutions = 0
#   --> output_filepath = /neurd_packages/meshAfterParty/meshAfterParty/apl_proofreading_utils.py
# --- Working on file: /neurd_packages/meshAfterParty/meshAfterParty/axon_utils.py
# --Getting files from /neurd_packages/pytorch_tools/pytorch_tools
# # of py files = 20
# # of substitutions = 0
#   --> output_filepath = /neurd_packages/meshAfterParty/meshAfterParty/axon_utils.py
# --- Working on file: /neurd_packages/meshAfterParty/meshAfterParty/branch_attr_utils.py
# --Getting files from /neurd_packages/pytorch_tools/pytorch_tools
# # of py files = 20
# # of substitutions = 0
#   --> output_filepath = /neurd_packages/meshAfterParty/meshAfterParty/branch_attr_utils.py
# --- Working on file: /neurd_packages/meshAfterParty/meshAfterParty/branch_utils.py
# --Getting files from /neurd_packages/pytorch_tools/pytorch_tools
# # of py files = 20
# # of substitutions = 0
#   --> output_filepath = /neurd_packages/meshAfterParty/meshAfterParty/branch_utils.py
# --- Working on file: /neurd_packages/meshAfterParty/meshAfterParty/cell_type_catalog.py
# --Getting files from /neurd_packages/pytorch_tools/pytorch_tools
# # of py files = 20
# # of substitutions = 0
#   --> output_filepath = /neurd_packages/meshAfterParty/meshAfterParty/cell_type_catalog.py
# --- Working on file: /neurd_packages/meshAfterParty/meshAfterParty/cell_type_conv_utils.py
# --Getting files from /neurd_packages/pytorch_tools/pytorch_tools
# # of py files = 20
# # of substitutions = 0
#   --> output_filepath = /neurd_packages/meshAfterParty/meshAfterParty/cell_type_conv_utils.py
# --- Working on file: /neurd_packages/meshAfterParty/meshAfterParty/cell_type_utils.py
# --Getting files from /neurd_packages/pytorch_tools/pytorch_tools
# # of py files = 20
# # of substitutions = 0
#   --> output_filepath = /neurd_packages/meshAfterParty/meshAfterParty/cell_type_utils.py
# --- Working on file: /neurd_packages/meshAfterParty/meshAfterParty/classification_utils.py
# --Getting files from /neurd_packages/pytorch_tools/pytorch_tools
# # of py files = 20
# # of substitutions = 0
#   --> output_filepath = /neurd_packages/meshAfterParty/meshAfterParty/classification_utils.py
# --- Working on file: /neurd_packages/meshAfterParty/meshAfterParty/clustering_utils.py
# --Getting files from /neurd_packages/pytorch_tools/pytorch_tools
# # of py files = 20
# # of substitutions = 0
#   --> output_filepath = /neurd_packages/meshAfterParty/meshAfterParty/clustering_utils.py
# --- Working on file: /neurd_packages/meshAfterParty/meshAfterParty/compartment_ori_catalog.py
# --Getting files from /neurd_packages/pytorch_tools/pytorch_tools
# # of py files = 20
# # of substitutions = 0
#   --> output_filepath = /neurd_packages/meshAfterParty/meshAfterParty/compartment_ori_catalog.py
# --- Working on file: /neurd_packages/meshAfterParty/meshAfterParty/compartment_utils.py
# --Getting files from /neurd_packages/pytorch_tools/pytorch_tools
# # of py files = 20
# # of substitutions = 0
#   --> output_filepath = /neurd_packages/meshAfterParty/meshAfterParty/compartment_utils.py
# --- Working on file: /neurd_packages/meshAfterParty/meshAfterParty/concept_network_utils.py
# --Getting files from /neurd_packages/pytorch_tools/pytorch_tools
# # of py files = 20
# # of substitutions = 0
#   --> output_filepath = /neurd_packages/meshAfterParty/meshAfterParty/concept_network_utils.py
# --- Working on file: /neurd_packages/meshAfterParty/meshAfterParty/connectome_analysis_utils.py
# --Getting files from /neurd_packages/pytorch_tools/pytorch_tools
# # of py files = 20
# # of substitutions = 0
#   --> output_filepath = /neurd_packages/meshAfterParty/meshAfterParty/connectome_analysis_utils.py
# --- Working on file: /neurd_packages/meshAfterParty/meshAfterParty/connectome_filtering.py
# --Getting files from /neurd_packages/pytorch_tools/pytorch_tools
# # of py files = 20
# # of substitutions = 0
#   --> output_filepath = /neurd_packages/meshAfterParty/meshAfterParty/connectome_filtering.py
# --- Working on file: /neurd_packages/meshAfterParty/meshAfterParty/connectome_query_utils.py
# --Getting files from /neurd_packages/pytorch_tools/pytorch_tools
# # of py files = 20
# # of substitutions = 0
#   --> output_filepath = /neurd_packages/meshAfterParty/meshAfterParty/connectome_query_utils.py
# --- Working on file: /neurd_packages/meshAfterParty/meshAfterParty/connectome_utils.py
# --Getting files from /neurd_packages/pytorch_tools/pytorch_tools
# # of py files = 20
# # of substitutions = 0
#   --> output_filepath = /neurd_packages/meshAfterParty/meshAfterParty/connectome_utils.py
# --- Working on file: /neurd_packages/meshAfterParty/meshAfterParty/dataInterface.py
# --Getting files from /neurd_packages/pytorch_tools/pytorch_tools
# # of py files = 20
# # of substitutions = 0
#   --> output_filepath = /neurd_packages/meshAfterParty/meshAfterParty/dataInterface.py
# --- Working on file: /neurd_packages/meshAfterParty/meshAfterParty/dataInterfaceH01.py
# --Getting files from /neurd_packages/pytorch_tools/pytorch_tools
# # of py files = 20
# # of substitutions = 0
#   --> output_filepath = /neurd_packages/meshAfterParty/meshAfterParty/dataInterfaceH01.py
# --- Working on file: /neurd_packages/meshAfterParty/meshAfterParty/dataInterfaceMinnie65.py
# --Getting files from /neurd_packages/pytorch_tools/pytorch_tools
# # of py files = 20
# # of substitutions = 0
#   --> output_filepath = /neurd_packages/meshAfterParty/meshAfterParty/dataInterfaceMinnie65.py
# --- Working on file: /neurd_packages/meshAfterParty/meshAfterParty/datajoint_motifs.py
# --Getting files from /neurd_packages/pytorch_tools/pytorch_tools
# # of py files = 20
# # of substitutions = 0
#   --> output_filepath = /neurd_packages/meshAfterParty/meshAfterParty/datajoint_motifs.py
# --- Working on file: /neurd_packages/meshAfterParty/meshAfterParty/datajoint_utils.py
# --Getting files from /neurd_packages/pytorch_tools/pytorch_tools
# # of py files = 20
# # of substitutions = 0
#   --> output_filepath = /neurd_packages/meshAfterParty/meshAfterParty/datajoint_utils.py
# --- Working on file: /neurd_packages/meshAfterParty/meshAfterParty/djp_documentation.py
# --Getting files from /neurd_packages/pytorch_tools/pytorch_tools
# # of py files = 20
# # of substitutions = 0
#   --> output_filepath = /neurd_packages/meshAfterParty/meshAfterParty/djp_documentation.py
# --- Working on file: /neurd_packages/meshAfterParty/meshAfterParty/dj_table_definitions.py
# --Getting files from /neurd_packages/pytorch_tools/pytorch_tools
# # of py files = 20
# # of substitutions = 0
#   --> output_filepath = /neurd_packages/meshAfterParty/meshAfterParty/dj_table_definitions.py
# --- Working on file: /neurd_packages/meshAfterParty/meshAfterParty/dotmotif_utils.py
# --Getting files from /neurd_packages/pytorch_tools/pytorch_tools
# # of py files = 20
# # of substitutions = 0
#   --> output_filepath = /neurd_packages/meshAfterParty/meshAfterParty/dotmotif_utils.py
# --- Working on file: /neurd_packages/meshAfterParty/meshAfterParty/ease_utils.py
# --Getting files from /neurd_packages/pytorch_tools/pytorch_tools
# # of py files = 20
# # of substitutions = 0
#   --> output_filepath = /neurd_packages/meshAfterParty/meshAfterParty/ease_utils.py
# --- Working on file: /neurd_packages/meshAfterParty/meshAfterParty/error_detection.py
# --Getting files from /neurd_packages/pytorch_tools/pytorch_tools
# # of py files = 20
# # of substitutions = 0
#   --> output_filepath = /neurd_packages/meshAfterParty/meshAfterParty/error_detection.py
# --- Working on file: /neurd_packages/meshAfterParty/meshAfterParty/functional_tuning_utils.py
# --Getting files from /neurd_packages/pytorch_tools/pytorch_tools
# # of py files = 20
# # of substitutions = 0
#   --> output_filepath = /neurd_packages/meshAfterParty/meshAfterParty/functional_tuning_utils.py
# --- Working on file: /neurd_packages/meshAfterParty/meshAfterParty/gmm.py
# --Getting files from /neurd_packages/pytorch_tools/pytorch_tools
# # of py files = 20
# # of substitutions = 0
#   --> output_filepath = /neurd_packages/meshAfterParty/meshAfterParty/gmm.py
# --- Working on file: /neurd_packages/meshAfterParty/meshAfterParty/gnn_embedding_utils.py
# --Getting files from /neurd_packages/pytorch_tools/pytorch_tools
# # of py files = 20
# # of substitutions = 1
#   --> output_filepath = /neurd_packages/meshAfterParty/meshAfterParty/gnn_embedding_utils.py
# --- Working on file: /neurd_packages/meshAfterParty/meshAfterParty/graph_filters.py
# --Getting files from /neurd_packages/pytorch_tools/pytorch_tools
# # of py files = 20
# # of substitutions = 0
#   --> output_filepath = /neurd_packages/meshAfterParty/meshAfterParty/graph_filters.py
# --- Working on file: /neurd_packages/meshAfterParty/meshAfterParty/graph_proofreading.py
# --Getting files from /neurd_packages/pytorch_tools/pytorch_tools
# # of py files = 20
# # of substitutions = 0
#   --> output_filepath = /neurd_packages/meshAfterParty/meshAfterParty/graph_proofreading.py
# --- Working on file: /neurd_packages/meshAfterParty/meshAfterParty/h01_dj_utils.py
# --Getting files from /neurd_packages/pytorch_tools/pytorch_tools
# # of py files = 20
# # of substitutions = 0
#   --> output_filepath = /neurd_packages/meshAfterParty/meshAfterParty/h01_dj_utils.py
# --- Working on file: /neurd_packages/meshAfterParty/meshAfterParty/h01_filtering_utils.py
# --Getting files from /neurd_packages/pytorch_tools/pytorch_tools
# # of py files = 20
# # of substitutions = 0
#   --> output_filepath = /neurd_packages/meshAfterParty/meshAfterParty/h01_filtering_utils.py
# --- Working on file: /neurd_packages/meshAfterParty/meshAfterParty/human_dj_utils.py
# --Getting files from /neurd_packages/pytorch_tools/pytorch_tools
# # of py files = 20
# # of substitutions = 0
#   --> output_filepath = /neurd_packages/meshAfterParty/meshAfterParty/human_dj_utils.py
# --- Working on file: /neurd_packages/meshAfterParty/meshAfterParty/human_utils.py
# --Getting files from /neurd_packages/pytorch_tools/pytorch_tools
# # of py files = 20
# # of substitutions = 0
#   --> output_filepath = /neurd_packages/meshAfterParty/meshAfterParty/human_utils.py
# --- Working on file: /neurd_packages/meshAfterParty/meshAfterParty/interesting_neurons.py
# --Getting files from /neurd_packages/pytorch_tools/pytorch_tools
# # of py files = 20
# # of substitutions = 0
#   --> output_filepath = /neurd_packages/meshAfterParty/meshAfterParty/interesting_neurons.py
# --- Working on file: /neurd_packages/meshAfterParty/meshAfterParty/limb_utils.py
# --Getting files from /neurd_packages/pytorch_tools/pytorch_tools
# # of py files = 20
# # of substitutions = 0
#   --> output_filepath = /neurd_packages/meshAfterParty/meshAfterParty/limb_utils.py
# --- Working on file: /neurd_packages/meshAfterParty/meshAfterParty/m65_neuron_catalog.py
# --Getting files from /neurd_packages/pytorch_tools/pytorch_tools
# # of py files = 20
# # of substitutions = 0
#   --> output_filepath = /neurd_packages/meshAfterParty/meshAfterParty/m65_neuron_catalog.py
# --- Working on file: /neurd_packages/meshAfterParty/meshAfterParty/machine_learning_utils.py
# --Getting files from /neurd_packages/pytorch_tools/pytorch_tools
# # of py files = 20
# # of substitutions = 0
#   --> output_filepath = /neurd_packages/meshAfterParty/meshAfterParty/machine_learning_utils.py
# --- Working on file: /neurd_packages/meshAfterParty/meshAfterParty/meshlab.py
# --Getting files from /neurd_packages/pytorch_tools/pytorch_tools
# # of py files = 20
# # of substitutions = 0
#   --> output_filepath = /neurd_packages/meshAfterParty/meshAfterParty/meshlab.py
# --- Working on file: /neurd_packages/meshAfterParty/meshAfterParty/meshparty_skeletonize.py
# --Getting files from /neurd_packages/pytorch_tools/pytorch_tools
# # of py files = 20
# # of substitutions = 0
#   --> output_filepath = /neurd_packages/meshAfterParty/meshAfterParty/meshparty_skeletonize.py
# --- Working on file: /neurd_packages/meshAfterParty/meshAfterParty/microns_graph_filtering.py
# --Getting files from /neurd_packages/pytorch_tools/pytorch_tools
# # of py files = 20
# # of substitutions = 0
#   --> output_filepath = /neurd_packages/meshAfterParty/meshAfterParty/microns_graph_filtering.py
# --- Working on file: /neurd_packages/meshAfterParty/meshAfterParty/microns_graph_query_utils.py
# --Getting files from /neurd_packages/pytorch_tools/pytorch_tools
# # of py files = 20
# # of substitutions = 0
#   --> output_filepath = /neurd_packages/meshAfterParty/meshAfterParty/microns_graph_query_utils.py
# --- Working on file: /neurd_packages/meshAfterParty/meshAfterParty/microns_volume_utils.py
# --Getting files from /neurd_packages/pytorch_tools/pytorch_tools
# # of py files = 20
# # of substitutions = 0
#   --> output_filepath = /neurd_packages/meshAfterParty/meshAfterParty/microns_volume_utils.py
# --- Working on file: /neurd_packages/meshAfterParty/meshAfterParty/module_test_2.py
# --Getting files from /neurd_packages/pytorch_tools/pytorch_tools
# # of py files = 20
# # of substitutions = 0
#   --> output_filepath = /neurd_packages/meshAfterParty/meshAfterParty/module_test_2.py
# --- Working on file: /neurd_packages/meshAfterParty/meshAfterParty/module_utils_old.py
# --Getting files from /neurd_packages/pytorch_tools/pytorch_tools
# # of py files = 20
# # of substitutions = 0
#   --> output_filepath = /neurd_packages/meshAfterParty/meshAfterParty/module_utils_old.py
# --- Working on file: /neurd_packages/meshAfterParty/meshAfterParty/morphology_analysis_utils.py
# --Getting files from /neurd_packages/pytorch_tools/pytorch_tools
# # of py files = 20
# # of substitutions = 0
#   --> output_filepath = /neurd_packages/meshAfterParty/meshAfterParty/morphology_analysis_utils.py
# --- Working on file: /neurd_packages/meshAfterParty/meshAfterParty/morphology_ori_utils.py
# --Getting files from /neurd_packages/pytorch_tools/pytorch_tools
# # of py files = 20
# # of substitutions = 0
#   --> output_filepath = /neurd_packages/meshAfterParty/meshAfterParty/morphology_ori_utils.py
# --- Working on file: /neurd_packages/meshAfterParty/meshAfterParty/morphology_queries_utils.py
# --Getting files from /neurd_packages/pytorch_tools/pytorch_tools
# # of py files = 20
# # of substitutions = 0
#   --> output_filepath = /neurd_packages/meshAfterParty/meshAfterParty/morphology_queries_utils.py
# --- Working on file: /neurd_packages/meshAfterParty/meshAfterParty/motif_utils.py
# --Getting files from /neurd_packages/pytorch_tools/pytorch_tools
# # of py files = 20
# # of substitutions = 0
#   --> output_filepath = /neurd_packages/meshAfterParty/meshAfterParty/motif_utils.py
# --- Working on file: /neurd_packages/meshAfterParty/meshAfterParty/movies_of_neurons.py
# --Getting files from /neurd_packages/pytorch_tools/pytorch_tools
# # of py files = 20
# # of substitutions = 0
#   --> output_filepath = /neurd_packages/meshAfterParty/meshAfterParty/movies_of_neurons.py
# --- Working on file: /neurd_packages/meshAfterParty/meshAfterParty/nature_paper_plotting.py
# --Getting files from /neurd_packages/pytorch_tools/pytorch_tools
# # of py files = 20
# # of substitutions = 0
#   --> output_filepath = /neurd_packages/meshAfterParty/meshAfterParty/nature_paper_plotting.py
# --- Working on file: /neurd_packages/meshAfterParty/meshAfterParty/neuron.py
# --Getting files from /neurd_packages/pytorch_tools/pytorch_tools
# # of py files = 20
# # of substitutions = 0
#   --> output_filepath = /neurd_packages/meshAfterParty/meshAfterParty/neuron.py
# --- Working on file: /neurd_packages/meshAfterParty/meshAfterParty/neuron_catalog_human.py
# --Getting files from /neurd_packages/pytorch_tools/pytorch_tools
# # of py files = 20
# # of substitutions = 0
#   --> output_filepath = /neurd_packages/meshAfterParty/meshAfterParty/neuron_catalog_human.py
# --- Working on file: /neurd_packages/meshAfterParty/meshAfterParty/neuron_catalog_v6.py
# --Getting files from /neurd_packages/pytorch_tools/pytorch_tools
# # of py files = 20
# # of substitutions = 0
#   --> output_filepath = /neurd_packages/meshAfterParty/meshAfterParty/neuron_catalog_v6.py
# --- Working on file: /neurd_packages/meshAfterParty/meshAfterParty/neuron_catalog_v7.py
# --Getting files from /neurd_packages/pytorch_tools/pytorch_tools
# # of py files = 20
# # of substitutions = 0
#   --> output_filepath = /neurd_packages/meshAfterParty/meshAfterParty/neuron_catalog_v7.py
# --- Working on file: /neurd_packages/meshAfterParty/meshAfterParty/neuron_geometry_utils.py
# --Getting files from /neurd_packages/pytorch_tools/pytorch_tools
# # of py files = 20
# # of substitutions = 0
#   --> output_filepath = /neurd_packages/meshAfterParty/meshAfterParty/neuron_geometry_utils.py
# --- Working on file: /neurd_packages/meshAfterParty/meshAfterParty/neuron_searching.py
# --Getting files from /neurd_packages/pytorch_tools/pytorch_tools
# # of py files = 20
# # of substitutions = 0
#   --> output_filepath = /neurd_packages/meshAfterParty/meshAfterParty/neuron_searching.py
# --- Working on file: /neurd_packages/meshAfterParty/meshAfterParty/neuron_simplification.py
# --Getting files from /neurd_packages/pytorch_tools/pytorch_tools
# # of py files = 20
# # of substitutions = 0
#   --> output_filepath = /neurd_packages/meshAfterParty/meshAfterParty/neuron_simplification.py
# --- Working on file: /neurd_packages/meshAfterParty/meshAfterParty/neuron_statistics.py
# --Getting files from /neurd_packages/pytorch_tools/pytorch_tools
# # of py files = 20
# # of substitutions = 0
#   --> output_filepath = /neurd_packages/meshAfterParty/meshAfterParty/neuron_statistics.py
# --- Working on file: /neurd_packages/meshAfterParty/meshAfterParty/neuron_utils.py
# --Getting files from /neurd_packages/pytorch_tools/pytorch_tools
# # of py files = 20
# # of substitutions = 0
#   --> output_filepath = /neurd_packages/meshAfterParty/meshAfterParty/neuron_utils.py
# --- Working on file: /neurd_packages/meshAfterParty/meshAfterParty/neuron_visualizations.py
# --Getting files from /neurd_packages/pytorch_tools/pytorch_tools
# # of py files = 20
# # of substitutions = 0
#   --> output_filepath = /neurd_packages/meshAfterParty/meshAfterParty/neuron_visualizations.py
# --- Working on file: /neurd_packages/meshAfterParty/meshAfterParty/preprocessing_vp2.py
# --Getting files from /neurd_packages/pytorch_tools/pytorch_tools
# # of py files = 20
# # of substitutions = 0
#   --> output_filepath = /neurd_packages/meshAfterParty/meshAfterParty/preprocessing_vp2.py
# --- Working on file: /neurd_packages/meshAfterParty/meshAfterParty/preprocess_neuron.py
# --Getting files from /neurd_packages/pytorch_tools/pytorch_tools
# # of py files = 20
# # of substitutions = 0
#   --> output_filepath = /neurd_packages/meshAfterParty/meshAfterParty/preprocess_neuron.py
# --- Working on file: /neurd_packages/meshAfterParty/meshAfterParty/proofreading_utils.py
# --Getting files from /neurd_packages/pytorch_tools/pytorch_tools
# # of py files = 20
# # of substitutions = 0
#   --> output_filepath = /neurd_packages/meshAfterParty/meshAfterParty/proofreading_utils.py
# --- Working on file: /neurd_packages/meshAfterParty/meshAfterParty/proofread_verification.py
# --Getting files from /neurd_packages/pytorch_tools/pytorch_tools
# # of py files = 20
# # of substitutions = 0
#   --> output_filepath = /neurd_packages/meshAfterParty/meshAfterParty/proofread_verification.py
# --- Working on file: /neurd_packages/meshAfterParty/meshAfterParty/proximity_analysis_utils.py
# --Getting files from /neurd_packages/pytorch_tools/pytorch_tools
# # of py files = 20
# # of substitutions = 0
#   --> output_filepath = /neurd_packages/meshAfterParty/meshAfterParty/proximity_analysis_utils.py
# --- Working on file: /neurd_packages/meshAfterParty/meshAfterParty/proximity_utils.py
# --Getting files from /neurd_packages/pytorch_tools/pytorch_tools
# # of py files = 20
# # of substitutions = 0
#   --> output_filepath = /neurd_packages/meshAfterParty/meshAfterParty/proximity_utils.py
# --- Working on file: /neurd_packages/meshAfterParty/meshAfterParty/reconstruction_utils.py
# --Getting files from /neurd_packages/pytorch_tools/pytorch_tools
# # of py files = 20
# # of substitutions = 0
#   --> output_filepath = /neurd_packages/meshAfterParty/meshAfterParty/reconstruction_utils.py
# --- Working on file: /neurd_packages/meshAfterParty/meshAfterParty/skeleton_utils.py
# --Getting files from /neurd_packages/pytorch_tools/pytorch_tools
# # of py files = 20
# # of substitutions = 0
#   --> output_filepath = /neurd_packages/meshAfterParty/meshAfterParty/skeleton_utils.py
# --- Working on file: /neurd_packages/meshAfterParty/meshAfterParty/soma_extraction_utils.py
# --Getting files from /neurd_packages/pytorch_tools/pytorch_tools
# # of py files = 20
# # of substitutions = 0
#   --> output_filepath = /neurd_packages/meshAfterParty/meshAfterParty/soma_extraction_utils.py
# --- Working on file: /neurd_packages/meshAfterParty/meshAfterParty/spine_catelog.py
# --Getting files from /neurd_packages/pytorch_tools/pytorch_tools
# # of py files = 20
# # of substitutions = 0
#   --> output_filepath = /neurd_packages/meshAfterParty/meshAfterParty/spine_catelog.py
# --- Working on file: /neurd_packages/meshAfterParty/meshAfterParty/spine_utils.py
# --Getting files from /neurd_packages/pytorch_tools/pytorch_tools
# # of py files = 20
# # of substitutions = 0
#   --> output_filepath = /neurd_packages/meshAfterParty/meshAfterParty/spine_utils.py
# --- Working on file: /neurd_packages/meshAfterParty/meshAfterParty/spine_validation_utils.py
# --Getting files from /neurd_packages/pytorch_tools/pytorch_tools
# # of py files = 20
# # of substitutions = 0
#   --> output_filepath = /neurd_packages/meshAfterParty/meshAfterParty/spine_validation_utils.py
# --- Working on file: /neurd_packages/meshAfterParty/meshAfterParty/synapse_utils.py
# --Getting files from /neurd_packages/pytorch_tools/pytorch_tools
# # of py files = 20
# # of substitutions = 0
#   --> output_filepath = /neurd_packages/meshAfterParty/meshAfterParty/synapse_utils.py
# --- Working on file: /neurd_packages/meshAfterParty/meshAfterParty/trimesh_utils.py
# --Getting files from /neurd_packages/pytorch_tools/pytorch_tools
# # of py files = 20
# # of substitutions = 0
#   --> output_filepath = /neurd_packages/meshAfterParty/meshAfterParty/trimesh_utils.py
# --- Working on file: /neurd_packages/meshAfterParty/meshAfterParty/validation_cells.py
# --Getting files from /neurd_packages/pytorch_tools/pytorch_tools
# # of py files = 20
# # of substitutions = 0
#   --> output_filepath = /neurd_packages/meshAfterParty/meshAfterParty/validation_cells.py
# --- Working on file: /neurd_packages/meshAfterParty/meshAfterParty/validation_utils.py
# --Getting files from /neurd_packages/pytorch_tools/pytorch_tools
# # of py files = 20
# # of substitutions = 0
#   --> output_filepath = /neurd_packages/meshAfterParty/meshAfterParty/validation_utils.py
# --- Working on file: /neurd_packages/meshAfterParty/meshAfterParty/whole_neuron_classifier_datajoint_adapted.py
# --Getting files from /neurd_packages/pytorch_tools/pytorch_tools
# # of py files = 20
# # of substitutions = 0
#   --> output_filepath = /neurd_packages/meshAfterParty/meshAfterParty/whole_neuron_classifier_datajoint_adapted.py
# --- Working on file: /neurd_packages/meshAfterParty/meshAfterParty/width_utils.py
# --Getting files from /neurd_packages/pytorch_tools/pytorch_tools
# # of py files = 20
# # of substitutions = 0
#   --> output_filepath = /neurd_packages/meshAfterParty/meshAfterParty/width_utils.py
# --- Working on file: /neurd_packages/neuron_morphology_tools/neuron_morphology_tools/morphopy_utils.py
# --Getting files from /neurd_packages/pytorch_tools/pytorch_tools
# # of py files = 20
# # of substitutions = 0
#   --> output_filepath = /neurd_packages/neuron_morphology_tools/neuron_morphology_tools/morphopy_utils.py
# --- Working on file: /neurd_packages/neuron_morphology_tools/neuron_morphology_tools/neuron_nx_feature_processing.py
# --Getting files from /neurd_packages/pytorch_tools/pytorch_tools
# # of py files = 20
# # of substitutions = 0
#   --> output_filepath = /neurd_packages/neuron_morphology_tools/neuron_morphology_tools/neuron_nx_feature_processing.py
# --- Working on file: /neurd_packages/neuron_morphology_tools/neuron_morphology_tools/neuron_nx_io.py
# --Getting files from /neurd_packages/pytorch_tools/pytorch_tools
# # of py files = 20
# # of substitutions = 0
#   --> output_filepath = /neurd_packages/neuron_morphology_tools/neuron_morphology_tools/neuron_nx_io.py
# --- Working on file: /neurd_packages/neuron_morphology_tools/neuron_morphology_tools/neuron_nx_stats.py
# --Getting files from /neurd_packages/pytorch_tools/pytorch_tools
# # of py files = 20
# # of substitutions = 0
#   --> output_filepath = /neurd_packages/neuron_morphology_tools/neuron_morphology_tools/neuron_nx_stats.py
# --- Working on file: /neurd_packages/neuron_morphology_tools/neuron_morphology_tools/neuron_nx_utils.py
# --Getting files from /neurd_packages/pytorch_tools/pytorch_tools
# # of py files = 20
# # of substitutions = 0
#   --> output_filepath = /neurd_packages/neuron_morphology_tools/neuron_morphology_tools/neuron_nx_utils.py
# --- Working on file: /neurd_packages/neuron_morphology_tools/neuron_morphology_tools/neuron_skeleton_utils.py
# --Getting files from /neurd_packages/pytorch_tools/pytorch_tools
# # of py files = 20
# # of substitutions = 0
#   --> output_filepath = /neurd_packages/neuron_morphology_tools/neuron_morphology_tools/neuron_skeleton_utils.py
# --- Working on file: /neurd_packages/neuron_morphology_tools/neuron_morphology_tools/__init__.py
# --Getting files from /neurd_packages/pytorch_tools/pytorch_tools
# # of py files = 20
# # of substitutions = 0
#   --> output_filepath = /neurd_packages/neuron_morphology_tools/neuron_morphology_tools/__init__.py

# %% [markdown]
# # Requirmenets (from in the bash if fail to get error message)

# %%
from python_tools import requirement_utils as requ

# %%
# Generate the requirements package
from python_tools import requirement_utils as requ

req_dict = requ.requirements_dict_from_directories(
    directories=(directory_name,),
    verbose = True,
)
req_dict
# Out:
#   0%|          | 0/1 [00:00<?, ?it/s]
# command = pipreqs --encoding=utf8 --force pytorch_tools --ignore=pytorch_tools/.ipynb_checkpoints,pytorch_tools/HGP_SL,pytorch_tools/pytorch_geometric_resources.txt,pytorch_tools/requirements.txt,pytorch_tools/untitled.txt,pytorch_tools/untitled1.txt --mode gt --savepath /neurd_packages/pytorch_tools/requirements.txt
# 100%|██████████| 1/1 [00:02<00:00,  2.96s/it]
# Package Diff: ['collections' 'copy' 'math' 'meshAfterParty' 'models'
#  'neuron_morphology_tools' 'os' 'pathlib' 'pytorch_tools' 'tensorflow'
#  'time' 'types' 'typing']
# {'pytorch_tools': {'dgl': '1.1.0',
#   'networkx': '2.5',
#   'numpy': '1.19.5',
#   'pandas': '1.1.5',
#   'python_tools': '0.0.1',
#   'tensorboard': '2.6.0',
#   'torch': '1.10.2+cpu',
#   'torch_geometric': '2.0.3',
#   'torch_sparse': '0.6.12',
#   'ipython': None,
#   'ipython_genutils': None}}

# %% [markdown]
# # Do the setup.py

# %%
from python_tools import setup_py_utils as setu
setu.setup_py_str_generator(
    directory_name,
    output_path="./setup.py"
)
# Out:
# 'from pathlib import Path\nfrom setuptools import setup, find_packages\nfrom typing import List\n\ndef get_install_requires(filepath=None):\n    if filepath is None:\n        filepath = "./"\n    """Returns requirements.txt parsed to a list"""\n    fname = Path(filepath).parent / \'requirements.txt\'\n    targets = []\n    if fname.exists():\n        with open(fname, \'r\') as f:\n            targets = f.read().splitlines()\n    return targets\n\ndef get_links():\n    return [\n        #"git+https://github.com/bacelii/machine_learning_tools.git"\n    ]\n\n\n\nsetup(\n    name=\'pytorch_tools\', # the name of the package, which can be different than the folder when using pip instal\n    version=\'1.0.0\',\n    description=\'\',\n    author=\'Brendan Celii\',\n    author_email=\'brendanacelii\',\n    packages=find_packages(),  #teslls what packages to be included for the install\n    install_requires=get_install_requires(), #external packages as dependencies\n    dependency_links = get_links(),\n    # if wanted to install with the extra requirements use pip install -e ".[interactive]"\n    extras_require={\n        #\'interactive\': [\'matplotlib>=2.2.0\', \'jupyter\'],\n    },\n    \n    # if have a python script that wants to be run from the command line\n    entry_points={\n        #\'console_scripts\': [\'pipeline_download=Applications.Eleox_Data_Fetch.Eleox_Data_Fetcher_vp1:main\']\n    },\n    scripts=[], \n    \n)\n\n'

# %% [markdown]
# # Try to pip install (and manually fix any versions that have conflicts, like with python version)

# %%
#!pip3 install -e .

# %% [markdown]
# # Create the github documentation (instructions in documentation.txt)

# %%
import umap

# %%
dir(umap)

# %% [markdown]
# # --- Debug --

# %%
data = """
from python_tools import hi
from graph_tools import joe, shcmo
"""

from python_tools import module_utils as modu
modu.find_import_modules_in_file(data = data)

# %%
modu.clean_module_syntax(
    filepath = "/neurd_packages/machine_learning_tools/machine_learning_tools/visualizations_ml.py",
    overwrite=False,
    verbose = True
)

# %%
modu.find_import_modules_in_file(
    "/neurd_packages/machine_learning_tools/machine_learning_tools/visualizations_ml.py",
    verbose_import_pattern = True
)
